# %%
from scipy.special import binom
from scipy.special import beta as B
import matplotlib.pyplot as plt
import numpy as np

def gen_probs(n, a, b):
    probs = np.zeros(n+1)
    for k in range(n+1):
        probs[k] = binom(n, k) * B(k + a, n - k + b) / B(a, b)
    return probs
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
n = 10
a_vals = [0.01, .1, 1, 10]
b_vals = [0.01, .1, 1, 10]
fig, ax = plt.subplots()
for a, b in zip(a_vals, b_vals):
    ab_label = r'$a = %.1f$, $b = %.1f$' % (a, b)
    ax.plot(range(0, n+1), gen_probs(n, a, b), '-o', label=ab_label)
ax.legend()
plt.show()

# %%
##posterior mean of the beta-binomial process
def post_mean(a,b,k):
    return (a+k)/(a+b+1)
a,b = np.meshgrid(np.logspace(-6, 0.5, num=10),np.logspace(-6, 0.5, num=10))
probs_on = post_mean(a,b,1)
probs_off = post_mean(a,b,0)
#probs_on = np.empty(shape = a.shape)
#probs_off = np.empty(shape = a.shape)

#for ii,val_a in enumerate(a):
#    for jj,val_b in enumerate(a):
#        probs_off[ii,jj] = post_mean(val_a, val_b, 0)
#        probs_on[ii,jj] = post_mean(val_a, val_b, 1)

# %%
# Out:
# (10, 10)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
fig = figure()
ax = Axes3D(fig)
ax.plot_surface(a,b, probs_off, cmap = cm.coolwarm)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
        linewidth=0, antialiased=False)
ax.set_zlim(-1.01, 1.01)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x57fb758>
# <matplotlib.colorbar.Colorbar instance at 0x5b0aab8>
