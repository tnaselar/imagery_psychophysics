# %%
##my stuff
from imagery_psychophysics.src.stirling_maps import sparse_point_maps as spm
from imagery_psychophysics.src.model_z import noise_grid

##other people's stuff
import math
import copy
import numpy as np
import pandas as pd

from fractions import gcd
from PIL.Image import open
from PIL import Image
from scipy.misc import imresize
from os.path import join
from mpl_toolkits.axes_grid1 import ImageGrid
from matplotlib.colors import LinearSegmentedColormap
from scipy.misc import comb as nCk
from time import time
from theano import tensor as T
from theano.sandbox.rng_mrg import MRG_RandomStreams
from theano.tensor.shared_randomstreams import RandomStreams
from theano import function, shared
from theano.tensor.extra_ops import repeat, to_one_hot
from matplotlib import pyplot as plt
from matplotlib.mlab import griddata
# %matplotlib inline
# Out:
# /home/tnaselar/anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled, cuDNN not available)
# Couldn't import dot_parser, loading of dot files will not be possible.

# %% [markdown]
# ## In which we test the new-new code on some real data!

# %% [markdown]
#    ### Model variable classes

# %% [markdown]
# Utility variables needed for various things below

# %%
##a theano random number generator
rng = MRG_RandomStreams(use_cuda = True)

# %%
##data types
floatX = 'float32'
intX = 'int32'

# %%
##sometime we want to convert to 1hot format outside of theano expressions
##some compile the theano to_one_hot here
_anyVector = T.vector('anyMatrix',dtype=intX)
_anyInt = T.scalar('anyInt',dtype=intX)
to_one_hot_func = function(inputs=[_anyVector,_anyInt], outputs=to_one_hot(_anyVector, _anyInt))

# %% [markdown]
# Basic model dimensions

# %%
##defines number of objects in an object map
class numObjects(object):
    def __init__(self, largest=10):
        ##npy vars
        self.maxObjs = largest
        ##theano expressions
        self._K = T.scalar('numObjects',dtype='int32') ##a theano integer scalar
        
    def sample(self,M=1):
        return np.random.randint(1,self.maxObjs,size=M)
    
    def set_value(self,value):
        self.K = np.array(value,dtype=intX)

##number of pixels (row, col, total) in an object map
class numPixels(object):
    def __init__(self, largestRows=10,largestCols=10):
        ##npy vars
        self.maxRows = largestRows
        self.maxCols = largestCols

        ##theano expressions
        self._D1 = T.scalar('numPixelRows',dtype='int32') ##num pixel rows
        self._D2 = T.scalar('numPixelCols',dtype='int32') ##num pixel cols
        self._D = self._D1*self._D2 ##total number of pixels
        self._D.name = 'numPixels'
        
    def sample(self,M=1):
        numRows = np.random.randint(1,self.maxRows,size=M) 
        numCols = np.random.randint(1,self.maxCols,size=M)
        numPixels = numRows*numCols
        return numRows,numCols,numPixels
    
    def set_value(self,D1,D2):
        self.D1 = np.array(D1,dtype=intX)
        self.D2 = np.array(D2,dtype=intX)
        self.D = D1*D2

# %% [markdown]
# Gamma-distributed hyperparameter for prior distribution over object categories

# %%
class priorDispersion(object):
    def __init__(self,maxDispersion=10):
        ##npy vars
        self.maxDispersion = maxDispersion
        ##theano exprs.
        self._dispersion = T.scalar('priorDispersionParam',dtype='float32')  ##dispersion of categorical distribution
        
    def sample(self,M=1):
        return np.random.gamma(self.maxDispersion,size=M)
        
    def set_value(self,value):
        self.dispersion = np.array(value,dtype=floatX)

# %% [markdown]
# The dirichlet-distributed K parameters that define multinomial object distribution prior

# %%
class categoryProbs(object):
    def __init__(self, numObjects_inst, priorDispersion_inst):
        self.priorDispersion = priorDispersion_inst
        self.numObjects = numObjects_inst
        self._pi= T.matrix('categoryPrior')  ##1 x K
        
    def sample(self,M=1):
        '''
        sample(M)
        generate M categorical distributions
        each categorical distribution is a (1 x K) draw from a dirichlet
        returns M x K numpy array of draws, each row an independent draw
        '''
        return np.random.dirichlet(np.repeat(self.priorDispersion.dispersion,self.numObjects.K),size=M)
    
    def set_value(self, value):
        self.pi = np.array(value,dtype=floatX)

# %% [markdown]
# The object map $Z$

# %%
class latentObjMap(object):
    def __init__(self,categoryPrior_inst, numPixels_inst):
        self.categoryPrior=categoryPrior_inst
        self.numPixels = numPixels_inst
        
        ##theano var for a stack of M object maps
        self._Z = T.tensor3('Z', dtype=intX) ##(M x K x D) ##M x K x D stack of one-hot object maps

        self.compile_sampler()
        
    def compile_sampler(self):
        _M = T.scalar('M',dtype='int32') ##number of samples
        _D = self.numPixels._D
        _K = self.categoryPrior.numObjects._K
        _pZ = T.matrix('pZ') ##(K x D) prior
        
        ##this will be an M x K x D int32 tensor
        _sampleZ = rng.multinomial(pvals = repeat(_pZ.T,_M,axis=0)).reshape((_D,_M,_K)).dimshuffle((1,2,0))
        self._Z_sample_func = function([_pZ,_M,_K,_D],outputs=_sampleZ)  
        
    def sample(self, M=1, pZ=None):
        '''
        sample(M=1)
        returns M x K x D numpy array of samples of 1hot encoded object maps.
        each pixel of each map is an i.i.d draw from a categorical prior
        '''
        K = self.categoryPrior.numObjects.K
        D = self.numPixels.D
        if pZ is None:
            catProbs = self.categoryPrior.pi
            pZ = np.repeat(catProbs.T, D, axis=1)
        thisM = np.array(M,dtype=intX)
        return self._Z_sample_func(pZ,thisM,K,D).astype(intX)
    
    def score(self,Z, given_params):
        #so this would be p(Z|pi), i.e. the prior on Z.
        #don't think I need this yet, so I'll pass.
        pass
    
    def view_sample(self, sampleZ, show=True):
        '''
        view_sample(sampleZ, show=True)
        takes a 1 x K x D sample of a 1hot encoded object map 
        and converts it to a D1 x D2 image of the map.
        
        makes plot if show=True
        '''
        sampleZImage = np.argmax(sampleZ,axis=1).reshape((self.numPixels.D1,self.numPixels.D2))
        if show:
            plt.imshow(sampleZImage, interpolation='nearest')
        return sampleZImage

# %% [markdown]
# #### The windows

# %%
foo = [(1,2),(2,4)]
print foo
foo.insert(0,(3,3))
print foo
# Out:
# [(1, 2), (2, 4)]
# [(3, 3), (1, 2), (2, 4)]

# %%
class probes(object):
    
    ##dumb initializer. Want to be able to process windows before assigning as attributes
    def __init__(self):
        pass

    
    def resolve(self, shape, workingScale=None):
        '''
        resolve(shape, workingScale=None)
        
        inputs:
            shape ~ shape tuple of the window probes (D1Prime, D2Prime)
            workingScale ~ integer multiple of smallest possible resolution that perfectly preserves aspect ratio
        
        outputs:
            resolutions ~ list of shape tuples. all possible downsamples that perfectly preserve aspect ratio
            workingResolution ~ shape tuple of the working scale used for the windows. pass along with windows to "reshape".
            
        You want a working scale that is small as possible without sacrificing any of the objects
        in the target image and preserves number of objects in smallest window and number of objects in most dense window.

        '''
     
        ##get the smallest permissable downsample
        greatestCommonDivisor = gcd(shape[0], shape[1])

        ##generate all permissable resolutions up to max (i.e. all integer rescalings)
        smallestResolution = (shape[0]/greatestCommonDivisor, shape[1]/greatestCommonDivisor)
        resolutions = [(ii*smallestResolution[0], ii*smallestResolution[1]) for ii in range(2,greatestCommonDivisor+1,2)]
        resolutions.insert(0,smallestResolution)
        ##get the working window resolution
        if workingScale is None:
            workingScale = -1
        
        workingResolution = resolutions[workingScale]
        
        return resolutions, workingResolution
    
    def reshape(self, windows, reshapeTo):
        
        ##downsample factor
        N = windows.shape[0]
        
        dns = np.prod(reshapeTo)/np.prod(windows.shape[-2])
        
        ##check that smallest window is greater than one pixel
        windowSizes = np.sum(np.sum(windows,axis=2),axis=1)
        
        smallestWindowSize = np.min(windowSizes)
        sizeOfThisWindowAfterDownsampling = smallestWindowSize*dns
        if sizeOfThisWindowAfterDownsampling < 1:
            raise ValueError('too much downsampling. smallest window less than one pixel')
        else:
            windows = np.array(map(lambda x: imresize(x,reshapeTo,interp='nearest', mode='L'), windows))
            
        
        return windows
    
    def set_value(self,windows,flatten = False):
        self.N,self.D1Prime,self.D2Prime = windows.shape
        self.DPrime = self.D1Prime*self.D2Prime
        if flatten:
            windows = windows.reshape((self.N,self.DPrime))
        self.windows = windows.astype(intX)

         
        
    
    def make_windows(self, makeWindows=False, stride = 1, sizes = [1], n_groups=7, group_order = 2):
        if makeWindows:
            Windows = []
            for sz in sizes:
                scale_count = 0
                for rows in np.arange(sz,D1,stride,dtype=int, ):
                    for cols in np.arange(sz,D2,stride,dtype=int):
                        one_win = np.zeros((D1,D2),dtype=floatX)
                        one_win[(rows-sz):(rows+sz), (cols-sz):(cols+sz)]=1
                        Windows.append(one_win)
                        scale_count +=1
                print scale_count


            N = len(Windows)
            n_groups *= D 
            W = np.zeros((N+n_groups,D),dtype=intX)
            for n in range(N):
                W[n,:] = Windows.pop().ravel()

            for n in range(N,N+n_groups):
                rand_pairs = np.random.permutation(N)[:group_order]
                W[n,:] = np.clip(np.sum(W[rand_pairs[0:group_order],:],axis=0), 0, 1)

            W = W[:(N+n_groups),:]


            N = W.shape[0]
            return W.astype(intX)

# %%
class target_image(object):
    def __init__(self):
        pass
    
    def set_values(self,targetObjectMap, targetImage=None):
        self.targetImage = targetImage
        values = np.array(np.unique(targetObjectMap))
        self.targetObjectMap = np.digitize(np.array(targetObjectMap), bins=values, right=True ).astype(intX)
        values = np.array(np.unique(targetObjectMap))
        self.numberTargetObjects = len(values)
        ##one-hot encoding
        D = np.prod(self.targetObjectMap.shape)
        K = self.numberTargetObjects
        self.testObjectMapOneHot = np.eye(K)[self.targetObjectMap.ravel()].T.reshape((1,K,D))

        
    def reshape(self,targetObjectMap, reshapeTo, targetImage=None):
        values = np.array(np.unique(targetObjectMap))
        imK = len(values)
        

        ##resize to window, checking for preserved number of objects
        testObjectMap=imresize(targetObjectMap, reshapeTo, interp='nearest')
        values = np.array(np.unique(testObjectMap))
        assert imK==len(values)

        ##digitize, checking 
        testObjectMap=np.digitize(np.array(testObjectMap), bins=values, right=True ).astype(int)
        values = np.array(np.unique(testObjectMap))
        assert imK==len(values)
        
        if targetImage is not None:
            testTargetImage = imresize(targetImage, reshapeTo, interp='nearest')
            return testObjectMap, testTargetImage
        else:
            return testObjectMap

# %% [markdown]
# The noise params $\theta_{+}, \theta_{-}$

# %%
class noiseParams(object):
    def __init__(self):
        pass
    def enumerate_param_grid(self,theta_dns):
        '''
        enumerate_param_grid(theta_dns)
        inputs:
        theta_dns ~ integer indicating roughly sqrt(G)*2, G = number of grid points
        outputs:
        noise_param ~ 2 x G np array. columns are pairs of noise params, [p_on; p_off]. p_off < p_on for each pair.
        '''
        p_on, p_off = noise_grid(theta_dns,theta_dns)
        return p_on, p_off

# %% [markdown]
# The observed responses $\mathbf{r}$

# %%
class responses(object):
    '''
    responses(latentObjMap_inst, noiseParams_inst)
    inputs:
        latentObjMap_inst, noiseParams_inst ~ instances of (see above)
    
    outputs:
        construct a responses instance with main attribute "lkhd_cube" that 
        allows to compute likelihood of responses given an object map Z
        
        can set observed responses to known windows using 'set_values'
    '''
    def __init__(self,latentObjMap_inst, noiseParams_inst):
        self.Z = latentObjMap_inst
        self.noise = noiseParams_inst
        
        ##a G x K x K cube of p(r|count,p_on,p_off)
        ##K = max count and/or response, G = number of noise params 
        self.lkhd_cube = T.tensor3('lkhd_cube')  
        
#         self.windows=windows ##N x D', where D' = number of stimulus pixels.
       
        
        
        self._W = T.matrix('windows', dtype=intX)
        self._DPrime = self._W.shape[1]
        
        self.compile_upsampler()
        self.compile_object_counter()
        
    def compile_upsampler(self):
        ##get theano vars for Z and it's dimensions
        _Z = self.Z._Z ##M x K x D stack of one-hot object maps
        _M = _Z.shape[0]
        _K = self.Z.categoryPrior.numObjects._K
        _D1 = self.Z.numPixels._D1
        _D2 = self.Z.numPixels._D2
        _D = self.Z.numPixels._D
        
        ##compute an upscale factor so we can upsample pixels in Z to match W
        _upscale = T.sqrt(self._DPrime // _D).astype(intX)
        
        ##this converts back to image format (M x D1 x D2), where D = D1*D2. int32
        _Z_images = _Z.argmax(axis=1).reshape((_M,_D1,_D2), ndim=3) 

        ##this upsamples the Z-maps to (M x D1' x D2'), where D' = D1'*D2'. still int32
        _Z_upsamples = T.tile(_Z_images.dimshuffle(0,1,2,'x','x'), (_upscale,_upscale)).transpose(0,1,3,2,4).reshape((_M,_D1*_upscale, _D2*_upscale))
        
        ##make a function so we can see upsampled object maps as images (if needed)
        self._Z_usample_image_func = function([_M, _D1, _D2, self._DPrime, _Z], outputs=_Z_upsamples)
        
        ##this converts the Z-maps back to a one-hot encoding (M x K x D'). 
        _Z_upsamples_one_hot = to_one_hot(_Z_upsamples.ravel(), _K,dtype=intX).reshape((_M, self._DPrime, _K)).transpose((0,2,1))
        self._Z_upsample_one_hot_func = function([_M, _K, _D1, _D2, self._DPrime, _Z], outputs=_Z_upsamples_one_hot)
    
    def compile_object_counter(self):

        _Z = self.Z._Z ##M x K x D stack of one-hot object maps
        _W = self._W
       
        ##(M x K x 1 x D')
        ##         N x D'
        ##(M x K x N x D')  sum(D')
        ##(M x K x N)      clip(0,1)
        ##(M x K x N)      sum(K)
        ##(M x N)
        self._object_counts = T.sum(_Z.dimshuffle((0,1,'x',2))*_W,axis=-1).clip(0,1).sum(axis=1)
        self._object_count_func = function([_Z, _W], outputs=self._object_counts)

    
    def compute_feature(self,Z, winIdx=None):
        '''
        compute_feature(Z, winIdx = None)
        the feature in this case is an object count over a map Z given a window W
        
        inputs:
            Z is an MxKxD stack of one-hot encoded object maps
            winIdx ~ array of window indices for getting responses.
                     if supplied, N' = len(winIdx), otherwise N' = total number of windows
        
        output:
            applies N'xD' matrix of windows to map Z, returns MxN' matrix of object counts
            note: if D != D', upsamples Z's so they each have D' pixels
        '''
        M = np.array(Z.shape[0],dtype=intX)
        K = self.Z.categoryPrior.numObjects.K
        D1 = self.Z.numPixels.D1
        D2 = self.Z.numPixels.D2
        D = self.Z.numPixels.D
        if winIdx is not None:
            windows = self.windows[winIdx]
        else:
            windows = self.windows
        if D != self.DPrime:
#             print 'upsampling'
            Z = self._Z_upsample_one_hot_func(M,K,D1,D2,self.DPrime,Z)
            
        return self._object_count_func(Z,windows)
    
    def score(self,r,c,p_on,p_off):
        '''
        calculates p(response | object_count, p_on, p_off), the strange likelihood I derived for this model
        
        score(response,object_count,p_on,p_off)
        inputs:
            response ~ integer
            object_count ~ integer
            p_on,p_off ~ noise params
        outputs:
            scalar likelihood value. 
        '''
        
        ##
        K = self.Z.categoryPrior.numObjects.K
        try:
            counts = np.array([nCk(c,m)*nCk(K-c, r-m) for m in range(min(r,c)+1)])
            probs = np.array([(1-p_on)**(c-m) * (p_on)**m * (p_off)**(r-m) * (1-p_off)**(K-c-r+m) for m in range(min(r,c)+1)])
            return counts.dot(probs)
        except TypeError:
            print 'Error in score. response and count should be integer-valued.'
            print r
            print c
            print min(r,c)
        
        
    
    def make_lkhd_cube(self,p_on, p_off):
        '''
        make_lkhd_cube(p_on,p_off)
        inputs:
            p_on,p_off ~ two array-likes of matching length=G giving pairs of noise params
        outputs:
            lkhd_cube ~ G x (K+1) x K tensor of "scores". dim1 = noise params, dim2 = responses, dim3 = conditioning counts
            The response dimension has size K+1 because subjects can respond 0 through K.
        
        '''
        K = self.Z.categoryPrior.numObjects.K
        countRange = np.arange(1,K+1,dtype=intX)
        respRange = np.arange(0,K+1,dtype=intX)
        G = len(p_on)
        lkhd_cube = np.full((G,K+1,K),0,dtype=floatX)
        for g,p in enumerate(zip(p_on,p_off)):
            for r in respRange:
                for c in countRange:
                    lkhd_cube[g,r,c-1]  = self.score(r,c,p[0],p[1])
        return lkhd_cube

        
    def sample(self,Z,p_on,p_off):
        
        '''
        sample(Z,p_on,p_off)
        inputs:
            Z   ~  M x K x D
            p_on,p_off ~ noise params

        returns
         noisy_object_counts  = M x N matrix of counts drawn i.i.d from likelihood

        this is not part of VI, so this is all done on cpu (no theano)
        '''
        M = Z.shape[0]  ##number of maps to sample
        K = self.Z.categoryPrior.numObjects.K
        object_counts = self.compute_feature(Z)
        N = object_counts.shape[1]
        sample_responses = np.zeros((M,N), dtype = intX)
        for m in range(M):
            for n in range(N):
                resp_dist = np.zeros(K+1)
                oc = np.int(object_counts[m,n])
                for k in range(K+1):
                    resp_dist[k] = self.score(k,oc,p_on,p_off)
                sample_responses[m,n]=np.argmax(np.random.multinomial(1,resp_dist))
        return sample_responses
    
    def set_values(self,data=None, windows=None):
        '''
        set_values(data, windows)
        inputs: supply either or both
            data ~ (1 x N) or (N x 1) or (N,) array of integer responses
            windows ~ instance of "probes" class containing (N x D') array of binary probes, where D' = = number of stimulus pixels.
        outputs:
            sets the observations attribute to data
            sets the windows attributes to windows
            
            checks for basic compatibility between windows and responses
        '''
        if data is not None:
            self.observations = np.squeeze(data) ##array of shape (N,)
        if windows is not None:
            
            self.windows = windows.windows ##N x D', where D' = number of stimulus pixels.
            self.N = self.windows.shape[0]
            self.DPrime = np.array(windows.windows.shape[1],dtype=intX)
            self.D1Prime = windows.D1Prime
            self.D2Prime = windows.D2Prime
            if self.DPrime != self.D1Prime*self.D2Prime:
                raise ValueError('aspect ratio of windows is not right')
        if hasattr(self,'observations') & hasattr(self, 'windows'):
            Nobs = self.observations.shape[0]
            if  Nobs != self.N:
                raise ValueError("number of windows (%d) and data points (%d) don't match" %(self.N, Nobs))
            if any(map(lambda x,y: x>y, self.observations, self.windows.sum(axis=1))):
                raise ValueError('some responses are larger than number of pixels in corresponding window. probably over-downsampled windows')

# %% [markdown]
# ### Inference classes

# %% [markdown]
# Define variational updates and optimization procedures for model variables

# %%
class inferQZ(object):
    def __init__(self):
        self.compile_updater()
        
    def compile_updater(self):
        ##K x N x K tensor of object count probs
        ##the first K is object id, the last K is object count
        _oc_probs = T.tensor3('oc_probs') 

        ##N x K, this will just be the log of P_star. 
        _lnP_star = T.matrix('lnP_star')

        ## K x 1, this is place holder for the dot product between pixel value and expected log of hyperparameters pi
        _v = T.matrix('prior_penalties')

              ##K x N x K oc_probs
        ##(tensordot)
                  ##N x K lnP_star 
              ##K x 1     lnQ_z
        ##(add V)
              ##K x 1
        ##(exp)
              ##K x 1     Q_z_nn
        ##(normalize)
              ##K x 1     Q_z, the variational posterior element for one pixel

        ##log of Q_z (minus unknown constant that normalizes things)    
        _lnQ_z = T.tensordot(_oc_probs, _lnP_star, [[1,2], [0,1]]).dimshuffle([0,'x'])+_v

        ##non-normalized Q_z. we shift by max value to stabilize upcoming exp
        _Q_z_nn = T.exp(_lnQ_z-T.max(_lnQ_z)) 

        ##variational posterior prob for one pixel
        _Q_z = _Q_z_nn / _Q_z_nn.sum()
        
        self._update_func = function([_oc_probs, _lnP_star, _v], outputs = _Q_z)

# %%
class optimizeNoiseParams(object):
    def __init__(self):
        'hi'
        
        
    def update_noiseParams(self, goodnessOfFit):
        '''
        update_noiseParams(goodnessOfFit)
        
        goodnessOfFit ~ G x 1 array of g.o.f. measures, one for each discrete candidate of noise params.
        returns max, argmax of this array
        
        '''
        ##find index of the best lkhd params (scalar integer)
        goodnessOfFitStar = np.max(goodnessOfFit)
        noiseParamStarIdx = np.argmax(goodnessOfFit)
        return goodnessOfFitStar, noiseParamStarIdx

# %%
class inferQPi(object):
    def __init__(self,):
        self.compile_updater()
        
    def compile_updater(self):
        _alpha_0 = T.scalar('alpha_0')
        _q_Z = T.matrix('q_Z')  ##K x 1, this is result of summing over pixels in Q_Z matrix. very different from Q_z

        _alpha = _q_Z + _alpha_0 ##broadcasts the scalar _alpha_0 across K

        ##(K x 1) this is needed to update Q_z
        _Eln_pi = T.psi(_alpha) - T.psi(_alpha.sum())

        ##(K x 1) not needed for update of variational posteriors, but we'll want it for model interpretation
        _E_pi = _alpha / _alpha.sum()
        
        ##returns _Eln_pi (K x 1) (object ids x 1)
        ##returns _E_pi (K x 1) (object ids x 1)
        self._update_func = function([_q_Z, _alpha_0], outputs = [_Eln_pi, _E_pi])

# %% [markdown]
# Variational inference for $q(Z)$, $q(\pi)$, noiseparams
#
# *Nasty book-keeping note*: counts, responses, and object id's are often converted to indices, or to 1hot formats.
# To convert counts to indices we need to subtract 1, because counts always range from 1 to K (inclusive),
# whereas indices range from 0 to K-1.
#
# To convert object id's to indices we don't need to subtract 1, because id's are coded from 0 to (K-1).
#
# To convert responses to indices we don't need to subtract, because responses range from 0 to K (inclusive).
# Becuase 0 to K (inclusive) is K+1 numbers, we do need to make sure that arrays for storing discrete responses have K+1 elements.
#
# Whew.

# %%
class VI(object):
    def __init__(self, responses_inst, inferQZ_inst, optimizeNoiseParams_inst, inferQPi_inst):
        self.responses = responses_inst
        self.iQZ = inferQZ_inst
        self.oNP = optimizeNoiseParams_inst
        self.iQPi = inferQPi_inst
        
        ##compile theano expressions, functions
        self.compile_object_probs()
        self.compile_ELBO()
        self.compile_predictive_distribution()
        self.compile_goodness_of_fit()
        
        

    ##===compile theano expressions, functions===
    def compile_object_probs(self):
        _object_counts = self.responses._object_counts ##(M x N)
        _K = self.responses.Z.categoryPrior.numObjects._K
        
        ##non-normalized object count probs (N x K)
        ##we are using these counts as indices, so we have to subtract 1
        _object_count_prob_nn = to_one_hot(_object_counts.astype('int32').flatten()-1,_K).reshape((_object_counts.shape[0],_object_counts.shape[1],_K)).sum(axis=0)

        ##object count probs (N x K)
        _object_count_prob = _object_count_prob_nn / _object_count_prob_nn.sum(axis=1).reshape((_object_count_prob_nn.shape[0], 1))
        
        self.object_count_prob_func = function([_object_counts, _K], outputs = _object_count_prob)
        
    def compile_goodness_of_fit(self):
        _P_theta = T.tensor3('_P_theta') ##(G x N x K)
        _oc_probs = T.matrix('oc_probs') ##N x K ~ this is a place holder for the "object count prob" matrix


        ##(G x N x K)
        ##(    N x K)  (dot product, broadcast across G)
        ##(G x 1)  --> because we don't do vectors we reshape to make output 2Dimensional (G x 1)

        ##log of likelihood

        _ln_P_theta = T.log(_P_theta)

        ##ln [q(theta+, theta-) - const (G x 1) ], the log of the unormalized variational distribution over theta
        ##currently we're taking a point estimate on theta so we don't do the hard normalization step.
        _goodnessOfFit = T.tensordot(_ln_P_theta, _oc_probs, axes=[[1,2], [0,1]],).reshape((_P_theta.shape[0], 1))
        
        ##returns G x 1 goodness of fit array. each element gives goodness of fit for one possible value of noiseparams
        self.goodness_of_fit_func = function([_P_theta, _oc_probs], outputs = _goodnessOfFit)
        
     
    def compile_ELBO(self):
        _goodnessOfFitStar = T.scalar('_goodnessOfFitStar') ##scalar

        _qZ = T.matrix('qZ_holder') ##N x K 

        ##scalar: the entropy of the variational posterior
        a_min = 10e-15
        a_max = 1
        _posterior_entropy = -T.tensordot(_qZ.clip(a_min,a_max), T.log(_qZ.clip(a_min,a_max)))

        ##scalar
        _ELBO = _goodnessOfFitStar  + _posterior_entropy
        self.ELBO_update_func = function([_qZ, _goodnessOfFitStar], outputs=[_goodnessOfFitStar, _posterior_entropy, _ELBO])

    def compile_predictive_distribution(self):
        _lkhdTable = T.matrix('lkhd_table_pred') ##K+1 x K ~ responses x counts, likelihood for fixed noiseparams
        
        ##windows x 1         x counts  |
        ##          responses x counts    tensordot
        ##windows x responses
        _oc_probs = T.matrix('oc_probs') ##N x K ~ this is a place holder for the "object count prob" matrix
        _pred_dist = T.tensordot(_oc_probs, _lkhdTable, axes = [[1],[1]])
        self.predictive_distribution_update_func = function(inputs=[_oc_probs,_lkhdTable], outputs=_pred_dist)
       
        
    ##====initialization methods
    
    def init_number_of_objects_range(self, numOverMin=1):
        
        ##the smallest number of objects has to be max response to any one probe
        smallestPossibleNumberOfObjects = np.max(self.curResponses).astype(intX)
        self.numberOfObjectsRange = np.arange(smallestPossibleNumberOfObjects, smallestPossibleNumberOfObjects+numOverMin+1)
        
        ##----there's also this complicated thing you could do...
#         maxResponseIdx = np.argmax(self.curResponses)
        
#         ##we'll cover a range from this minimum up to a number determined by probe sizes
#         sizeOfMaxResponseWindow = np.sum(self.responses.windows[self.curIdx[maxResponseIdx], :])
#         sizeOfLargestWindow = np.max(np.sum(self.responses.windows, axis=1))
#         differenceInWindowSizes = sizeOfLargestWindow - sizeOfMaxResponseWindow
        
#         largestNumberOfObjects = np.rint(np.min(smallestPossibleNumberOfObjects + hyperHyper*differenceInWindowSizes, self.hardcodedMaxNumberOfObjects)).astype(intX)
#         self.number_of_objects_range = np.arange(smallestPossibleNumberOfObjects, largestNumberOfObjects)
        
    def init_pixel_resolution_range(self, numOverMin = 1):
        
        D1Prime,D2Prime = self.responses.D1Prime, self.responses.D2Prime
        resolutions,_ = probes().resolve((D1Prime, D2Prime))
        self.pixelResolutionRange = resolutions[:numOverMin]
        
#         if not hasattr(self, 'pixel_resolution_range'):
#             if listOfTuples is None:
#                 raise ValueError('you gotta initialize pixel resolution range by hand. run init_pixel_resoltuion and supply list of shape tuples')
#             else:
#                 self.pixel_resolution_range = listOfTuples                
#         else:
#             print 'pixel resoltuion range already intialized by hand'
            
 
        
        
    
    ##select initial values of noiseparams, discretize, access lkhdCube
    def init_noiseParams(self, pOnInit, pOffInit,noiseParamNumber):
        '''
        init_noiseParams(pOnInit, pOffInit,noiseParamNumber)
        
        create a grid of candidate noise params according noiseParamNumber (i.e., something like square root of number
        of candidates we'll consider)
        
        take initial guess at noise param and return index of nearest candidate in the grid
        
        '''

        ##will need the likelihood cube at whatever resolution we're using to infer noise params, so make here
        self.noiseParamGrid = np.array(self.responses.noise.enumerate_param_grid(noiseParamNumber),dtype=floatX).T
        
        ##for starters, find index of closest noise param values to pOnInit, pOffInit, and then slice the lkhdCube
        noiseParamIdx = np.argmin(map(np.linalg.norm, self.noiseParamGrid-np.array([pOnInit,pOffInit]).T))
        return noiseParamIdx                                      
       
    
    def init_Eln_pi(self, qZ):
        dirichletParameter = self.responses.Z.categoryPrior.priorDispersion.dispersion
        Eln_pi, qPi = self.iQPi._update_func(qZ.sum(axis=1, keepdims=True), dirichletParameter)
        return Eln_pi, qPi
    
    def init_qZ(self, numStarterMaps, empiricalLkhdTableStar, dirichletParameter):
        '''
        qZ, startZ, starerLogs = init_q_Z(numStarterMaps, empiricalLkhdTable, dirichletParameter)
        
        randomly generates a stack of potential latent object maps.
        scores each Z according to p(responses | Z)
        selects Z with highest score = Z*
        constructs an initial qZ by sampling from dirichlet(Z[:,d]*+dirichletParameter) for each pixel d.
        
        inputs:
            numStartermaps ~ number of randomly generated Z's
            empiricalLkhdTable ~ N x K matrix of likelihoods p(response | count, pOn, pOff).
                                 noise params are implicit and assumed to be best guess at start of running vi.
                                 N can be either Ntrn, Ntest, or Nreg
            dirichletParameter ~ slop that you add to best Z to make a qZ
            
        outputs:
            qZ ~ K x D variational posterior
            startZ ~ the best object map from the randomly generated stack
            starterLogs ~ the l
        '''

        ##for generating stacks of one-hot-encoded object maps. these are "special" smooth maps
        def make_object_map_stack(K, num_rows, num_cols, image_dimensions,num_maps):
            size_of_field = int(np.mean(image_dimensions))
            D = np.prod(image_dimensions)
            object_map_base = spm(num_rows,num_cols,size_of_field,cluster_pref = 'random',number_of_clusters = K)
            object_maps = np.zeros((num_maps, K, D),dtype=intX)
            for nm in range(num_maps):
                object_map_base.scatter()
                tmp = np.squeeze(object_map_base.nn_interpolation())
                tmp = imresize(tmp, image_dimensions, interp='nearest')
                ##convert to one_hot encoding
                tmp = np.eye(K)[tmp.ravel()-1].T  ##K x D
                object_maps[nm] = tmp
            return object_maps

        ##generate candidate maps for starting iQ_Z
        K = self.responses.Z.categoryPrior.numObjects.K
        D1 = self.responses.Z.numPixels.D1
        D2 = self.responses.Z.numPixels.D2
        D = D1*D2
        objectMapStack = make_object_map_stack(K, 2*K, 2*K, (D1,D2), numStarterMaps)

        ##get table of log likelihoods for observed data
        logEmpiricalLkhdTable = np.log(empiricalLkhdTableStar)
  
        ##get object_counts ( M x N)
        objectCounts = self.responses.compute_feature(objectMapStack,winIdx=self.curIdx)

        ##get one-hot encoding of object counts (M x N x K)
        ##Use functionalized theano version
        ##we are using these counts as indices, so we have to subtract 1
        oneHotObjectCounts = to_one_hot_func(objectCounts.astype(intX).flatten()-1, K).reshape((objectCounts.shape[0],objectCounts.shape[1],K))
        


        ##evaluate log_likelihoods
        ## one_hot_object_counts = M x N x K
        ##            lkhd_table =     N x K tensordot
        ## observedLogLkhds = M x 1
        starterLogs = np.tensordot(oneHotObjectCounts, logEmpiricalLkhdTable, axes=2)
        bestStartMap = np.argmax(starterLogs)
        startZ = objectMapStack[bestStartMap] ## K x D
        
        qZ = np.zeros((K,D), dtype=floatX)
        for d in range(D): 
            qZ[:,d] = np.random.dirichlet(startZ[:,d]+dirichletParameter)
        return qZ, startZ, starterLogs
   

    ##==========update and optimization methods=============
    
    def optimize_hyper_parameters(self):
        bestPercentCorrect = 0
        bestK = np.inf
        bestD = np.inf
        for model in self.storedModels.values():
            if model.bestPercentCorrect > bestPercentCorrect:
                bestPercentCorrect = model.bestPercentCorrect
                bestModel = model
                bestK = model.responses.Z.categoryPrior.numObjects.K
                bestD = model.responses.Z.numPixels.D
            elif model.bestPercentCorrect == bestPercentCorrect:
                if (model.responses.Z.categoryPrior.numObjects.K < bestK) or (model.responses.Z.numPixels.D < bestD):
                    bestPercentCorrect = model.bestPercentCorrect
                    bestModel = model
                    bestK = model.responses.Z.categoryPrior.numObjects.K
                    bestD = model.responses.Z.numPixels.D
        return bestModel
            
    
    def update_qZ(self, qZ, ExpLnPi, noiseParamStarIdx):
        '''
        coordinate ascent on variational posteriors of object map pixels
        
        update_qZ(qZ, ExpLnPi, noiseParamStarIdx)
        
        '''
        
        ##PStar is our term for the empirical lkhd cube sliced at noiseParamStarIdx. it is N x K
        logPStar = np.log(self.curEmpiricalLkhdCube[noiseParamStarIdx])
        K = self.responses.Z.categoryPrior.numObjects.K
        D = self.responses.Z.numPixels.D
        for d in range(D):
            sampledZ = self.responses.Z.sample(M=self.numSamples, pZ=qZ)
            oc_probs = np.zeros((K, self.curN, K),dtype=floatX)
            v = np.zeros((K,1), dtype=floatX)
            for k in range(K): 
                sampledZ[:,:,d] = 0.    ##clear out object assignment for pixel d
                sampledZ[:,k, d] = 1.   ##assign pixel d to object k
                oc_counts = self.responses.compute_feature(sampledZ,winIdx=self.curIdx)
                oc_probs[k,:,:] = self.object_count_prob_func(oc_counts,K) ##calculate object count probs. given this assignment
                v[k] = np.dot(sampledZ[0,:,d], ExpLnPi,)        ##compare current assignment to prior over assignments
            qZ[:, d] = self.iQZ._update_func(oc_probs, logPStar, v).squeeze() ##update variational posterior for pixel d
        return qZ   

    def update_goodness_of_fit(self, qZ):
        '''
        update_goodness_of_fit(qZ)
        
        return G x 1 array of measures of how well the variational posterior qZ matches the data
        for each of the G possible values of the noise params.
        
        '''
        empiricalLkhdCube = self.curEmpiricalLkhdCube
        K = self.responses.Z.categoryPrior.numObjects.K
        
        sampledZ = self.responses.Z.sample(M=self.numSamples, pZ=qZ)
        oc_counts = self.responses.compute_feature(sampledZ,winIdx=self.curIdx)
        oc_probs = self.object_count_prob_func(oc_counts, K)
        
        goodnessOfFit = self.goodness_of_fit_func(empiricalLkhdCube, oc_probs)
        
        return goodnessOfFit
            
                                    
    def optimize_PStar(self,qZ):
        '''
        optimize_PStar(qZ)
        
        PStar is what we call the empirical lkhd cube sliced at the current best noise params.
        So, it is our current guess at the empricial lkhd table.
        
        We find the best noise param (by measuring goodness of fit)
        '''
        goodnessOfFit = self.update_goodness_of_fit(qZ)
        goodnessOfFitStar, noiseParamStarIdx = self.oNP.update_noiseParams(goodnessOfFit)

        ##N x K 
        PStar = self.curEmpiricalLkhdCube[noiseParamStarIdx]
        
        #1 x 2 best noiseparams
        noiseParamStar = self.noiseParamGrid[noiseParamStarIdx,:]
        return noiseParamStar, noiseParamStarIdx, PStar, goodnessOfFitStar
    
    def update_qPi(self, qZ):
        ##update prior params
        dirchletParam=self.responses.Z.categoryPrior.priorDispersion.dispersion
        ExpLnPi, qPi = self.iQPi._update_func(qZ.sum(axis=1, keepdims=True),dirchletParam)
        return ExpLnPi, qPi
    

        
    ##===criticism===        
    def update_ELBO(self, qZ, goodnessOfFitStar):
        goodnessOfFitStar, posterior_entropy, ELBO = self.ELBO_update_func(qZ,np.asscalar(goodnessOfFitStar))
        return goodnessOfFitStar, posterior_entropy, ELBO
        
    def update_log_predictive_distribution(self, qZ, noiseParamStarIdx):
        '''
        update_log_predictive_distribution(qZ, noiseParamStarIdx)
        inputs:
            qZ ~ K x D
            noiseParamStarIDx ~ int
        
        outputs:
            predictiveDistribution ~ N x K+1 distribution over the K+1 possible response to each of the N windows
            empiricalLogPredictiveDistribution ~ N x 1, this is log of predictiveDistribution sliced at empirical responses 
        '''
        ##create object count probabilities
        K = self.responses.Z.categoryPrior.numObjects.K       
        sampledZ = self.responses.Z.sample(M=self.numSamples, pZ=qZ)
        oc_counts = self.responses.compute_feature(sampledZ,winIdx=self.curIdx)
        oc_probs = self.object_count_prob_func(oc_counts, K)
        
        ##N x K+1, a distribution over K+1 responses to each window
        predictiveDistribution = self.predictive_distribution_update_func(oc_probs,self.lkhdCube[noiseParamStarIdx])
        
        ##slice the predictive  distribution at the actual responses
        ##note that responses can be used as indices without change (unlike counts)
        responsesAsIndices = self.curResponses.astype(intX)
        empiricalPredictiveDistribution = predictiveDistribution[range(self.curN), responsesAsIndices] ##(N x 1)
        
        ##N x 1
        logEmpiricalPredictiveDistribution = np.log(empiricalPredictiveDistribution)
        return predictiveDistribution, logEmpiricalPredictiveDistribution    
    
    
    def update_percent_correct(self, predictiveDistribution):
        
        responses = self.curResponses.astype(intX)
        predictions = np.argmax(predictiveDistribution, axis=1)
        fraction_correct = np.sum(responses==predictions) / (self.curN*1.)
        return fraction_correct*100, predictions
    
    def criticize(self, qZ, noiseParamStarIdx, goodnessOfFitStar, t):
        
        self.goodnessOfFitStar_history[t] = goodnessOfFitStar
        _,self.posteriorEntropy_history[t], self.ELBO_history[t] = self.update_ELBO(qZ, goodnessOfFitStar)
        
        ##get predictive distribution
        predictiveDistribution,logEmpiricalPredictiveDistribution = self.update_log_predictive_distribution(qZ, noiseParamStarIdx)
        
        ##sum to get probability of observed data under predictive distribution
        self.lnPredictiveDistribution_history[t] = logEmpiricalPredictiveDistribution.mean()
        
        ##use predicitive distribution to calculate percent correct
        self.percentCorrect_history[t],_ = self.update_percent_correct(predictiveDistribution)
        
        if self.percentCorrect_history[t] > self.bestPercentCorrect:
            print '!new best!'
            self.bestQZ = qZ.copy()
            self.bestNoiseParam = self.noiseParamGrid[noiseParamStarIdx,:].copy()
            self.bestPercentCorrect = self.percentCorrect_history[t]
            self.bestlnPredictiveDistribution = self.lnPredictiveDistribution_history[t]
        

        print 'ELBO: %f' %(self.ELBO_history[t])
        print 'goodness of fit: %f' %(goodnessOfFitStar)
        print 'posterior_entropy: %f' %(self.posteriorEntropy_history[t])
        print 'mean log of predictive distribution over test samples: %f' %(self.lnPredictiveDistribution_history[t])
        print 'pecent correct over test samples: %f' %(self.percentCorrect_history[t])
        print '\n'
        
        return 
    
        
    ##======utilities and bookeeping
    def rng_seed(self):
        if not hasattr(self, 'randNumberSeed'):
            self.randNumberSeed = np.random.randint(0,high=10**4)
        np.random.seed(self.randNumberSeed)
    
    def train_test_regularize_splits(self, trainTestSplit, trainRegSplit):
        N = self.responses.observations.shape[0]
        shuffledIdx = np.random.permutation(N)
        lastTestIdx = np.floor((1-trainTestSplit)*N)
        lastRegIdx = lastTestIdx+np.floor((1-trainRegSplit)*(N-lastTestIdx))
    
        testIdx = shuffledIdx[:lastTestIdx]
        regIdx = shuffledIdx[lastTestIdx:lastRegIdx]
        trainIdx = shuffledIdx[lastRegIdx:]
        return trainIdx, testIdx, regIdx
    
    def empirical_lkhd_cube(self, idx=None):
        if idx is None:
            respAsIdx = self.responses.observations.astype(intX)
        else:
            respAsIdx = self.responses.observations[idx].astype(intX)    
        return np.squeeze(self.lkhdCube[:,respAsIdx,:])
        
    def update_current(self, idx):
        self.curN = len(idx)
        self.curIdx = idx
        self.curIdx = self.curIdx
        self.curResponses = self.responses.observations[self.curIdx]
        try: ##because the computation graph is inelegant
            self.curEmpiricalLkhdCube = self.empirical_lkhd_cube(idx=self.curIdx)
        except:
            pass
        
        
    def store_learned_model(self):
        if not hasattr(self, 'storedModels'):
            self.storedModels = {0:copy.deepcopy(self)}
            
        else:
            newModelKey = np.max(self.storedModels.keys())+1
            self.storedModels[newModelKey] = copy.deepcopy(self)
            del self.storedModels[newModelKey].storedModels
        
    ##visualize the variational posterior over pixels
    def see_Q_Z(self, qZ, target_object_map = None, clim=[0,1]):
        ##view: construct an image grid
        fig = plt.figure(1, (30,10))
        K = qZ.shape[0]
        D1 = self.responses.Z.numPixels.D1
        D2 = self.responses.Z.numPixels.D2

        ##
        qZAsImageStack = qZ.reshape(K,D1,D2)
        if target_object_map is not None:
            K += 1
        grid = ImageGrid(fig, 111, # similar to subplot(111)
                        nrows_ncols = (1, K), # creates grid of axes
                        axes_pad=0.5, # pad between axes in inch.
                        cbar_mode = 'each',
                        cbar_pad = .05
                        )
        if target_object_map is not None:
            im = grid[0].imshow(target_object_map,cmap='Dark2', interpolation = 'nearest')
            grid[0].cax.colorbar(im)
            for kk in range(1,K):
                im = grid[kk].imshow(qZAsImageStack[kk-1], cmap='hot', clim=clim)
                grid[kk].cax.colorbar(im)

        else: 
            for kk in range(0,K):
                im = grid[kk].imshow(qZAsImageStack[kk], cmap='hot', clim=clim,interpolation = 'nearest')
                grid[kk].cax.colorbar(im)    
    
    ##=============RUN the actual variational inference algorithm========
    
    ##Note: the only arguments passed to the various methods should be those that are updated every iteration.
    def run_VI(self, initialNoisinessOfZ, pOnInit, pOffInit, noiseParamNumber, numStarterMaps, numSamples, maxIterations, trainTestSplit, trainRegSplit, optimizeHyperParams=True, pixelNumOverMin=3, objectNumOverMin=3):
      
        
        ##reset the rng seed
        self.rng_seed()

        ##divide the training, testing, regularization datasets
        trainIdx, testIdx, regIdx = self.train_test_regularize_splits(trainTestSplit=trainTestSplit, trainRegSplit=trainRegSplit)

        ##set empirical likelihoods, and responses to training set
        self.update_current(trainIdx)
        
        
        if optimizeHyperParams:
            ##collect the arguments for use in recursive call below
            allArgs = [initialNoisinessOfZ, pOnInit, pOffInit, noiseParamNumber, numStarterMaps, numSamples, maxIterations, trainTestSplit, trainRegSplit]
            
            ##initialize the ranges of hyperparameters
            self.init_number_of_objects_range(numOverMin=objectNumOverMin)
            self.init_pixel_resolution_range(numOverMin=pixelNumOverMin)
            
            ##run vi in a loop over hyperparameters
            for k in self.numberOfObjectsRange:
                self.responses.Z.categoryPrior.numObjects.set_value(k)
                print '--------number of objects: %d------------' %(self.responses.Z.categoryPrior.numObjects.K)
                for d1,d2 in self.pixelResolutionRange:
                    self.responses.Z.numPixels.set_value(d1,d2)
                    print '--------image resolution: (%d,%d,%d)------------' %(self.responses.Z.numPixels.D1,self.responses.Z.numPixels.D2,self.responses.Z.numPixels.D)
                    ##recursively call run_VI, each time with a fixed set of hyperparams, avoiding the hyperparameter loop
                    numIters=self.run_VI(*allArgs, optimizeHyperParams=False)
                    self.numIters = numIters
                    self.store_learned_model()
            bestModel = self.optimize_hyper_parameters()
            bestModel.trainIdx = trainIdx
            bestModel.regIdx = regIdx
            bestModel.testIdx = testIdx
            return bestModel
        else:


            ##--construct the lkhdCube and slice it at the discrete value of the noise params closest to the supplied init values
            noiseParamStarIdx = self.init_noiseParams(pOnInit, pOffInit, noiseParamNumber)

            ##store numSamples for consultation in a few functions
            self.numSamples = numSamples

            ##--construct lkhd cube
            self.lkhdCube = self.responses.make_lkhd_cube(self.noiseParamGrid[:,0],self.noiseParamGrid[:,1])  ##G x K x K

            ##set current empirical likelihoods, and responses to training set (have to re-run because of lkhdCube)
            self.update_current(trainIdx)

            ##initialize variational posterior
            qZ, self.startZ, self.starterLogs = self.init_qZ(numStarterMaps, self.curEmpiricalLkhdCube[noiseParamStarIdx], initialNoisinessOfZ)

            ##initialize variational prior
            ExpLnPi,_ = self.init_Eln_pi(qZ)

            ##get initial goodnessOfFitStar
            goodnessOfFitStar = self.update_goodness_of_fit(qZ)[noiseParamStarIdx]

            ##set initial PStar, which is our term for an empirical lkhd table evaluated at the noiseParamStarIdx
            ##PStar ~ N x K
            PStar = self.curEmpiricalLkhdCube[noiseParamStarIdx]

            ##--initialize arrays for learning histories and storing solutions
            iteration = 0
            self.ELBO_history = np.zeros((maxIterations+1,1))
            self.goodnessOfFitStar_history = np.zeros((maxIterations+1,1))
            self.posteriorEntropy_history = np.zeros((maxIterations+1,1))
            self.percentCorrect_history = np.zeros((maxIterations+1,1))
            self.lnPredictiveDistribution_history = np.zeros((maxIterations+1,1))
            self.bestPercentCorrect = 0

            delta_ELBO = np.inf
            min_delta_ELBO = 10e-15
            ELBO_old = 0.

            ##--publish initial criticism. use regularization data
            self.update_current(regIdx)
            self.criticize(qZ, noiseParamStarIdx, goodnessOfFitStar, iteration)

            ##switch back to training data
            self.update_current(trainIdx)

            iteration += 1


            while (delta_ELBO > min_delta_ELBO) and (iteration <= maxIterations):

                ##put lkhd in log domain
                lnPStar = np.log(PStar).astype(floatX)

                ##coordinate ascent on variational posteriors of object map pixels
                qZ = self.update_qZ(qZ, ExpLnPi, noiseParamStarIdx)


                ##update noise params: calculates goodness of fit for all possible noise params, finds best,
                ##returns it, returns best noiseParam, index of best noiseParam, and updates PStar
                noiseParamStar, noiseParamStarIdx, PStar, goodnessOfFitStar = self.optimize_PStar(qZ)

                ##update prior params
                ExpLnPi, _ = self.update_qPi(qZ)

                ##criticize using regularization data
                self.update_current(regIdx)
                self.criticize(qZ, noiseParamStarIdx, goodnessOfFitStar, iteration)

                ##switch back to training data
                self.update_current(trainIdx)

                ##update ELBO convergence criteria
                delta_ELBO = np.abs(self.ELBO_history[iteration]-ELBO_old)
                ELBO_old = self.ELBO_history[iteration]

                iteration += 1

            return iteration

# %% [markdown]
# #### Big dumb function for importing data

# %%
def open_imagery_probe_data(subject, state, targetImageName):
    '''
    open_imagery_probe_data(subject, state, targetImage)
    
    this only works one specific experiment
    have to know who the subjects are and the names of the target images
    state is either 'pcp' or 'img'
    
    '''
    ##which repo?
    drive = '/mnt/fast/'

    ##base directory
    base = 'multi_poly_probes'

    ##pandas dataframe with all the experimental conditions and data
    data_place = 'data'
    data_file = 'multi_poly_probe_data_3_subjects.pkl'

    ##open experimental data: this is a pandas dataframe
    experiment = pd.read_pickle(join(drive, base, data_place, data_file))


    ##target images
    image_place = 'target_images'
    mask_place = 'masks'

    target_image_file = targetImageName+'_letterbox.png'
    mask_image_file = targetImageName+'_mask.tif'

    ##window files
    window_place = 'probes'
    window_file = targetImageName+'_letterbox_img__probe_dict.pkl'
    
    ##open target image/object map: useful as a guide
    targetImage = open(join(drive, base, image_place, target_image_file),mode='r').convert('L')
    
    ##open
    targetObjectMap = open(join(drive, base, mask_place, mask_image_file),mode='r').convert('L')

    
    ##get the responses you want
    ##responses of select subject / target image / cognitive state
    resp = experiment[(experiment['image']==targetImageName) * (experiment['subj']==subject) * (experiment['state']==state)].response.values
    resp = resp[np.newaxis,:]
    
    ##corresponding window indices
    windowIdx = experiment[(experiment['image']==targetImageName) * (experiment['subj']==subject) * (experiment['state']==state)].probe.values


    
    ##open the windows. creates a dictionary with "index/mask" keys. this usually takes a while
    windows = pd.read_pickle(join(drive, base, window_place, window_file)) ##N x D1Prime x D2Prime
    N = len(windows['index'])
    window_shape = windows['mask'][0].shape
    W = np.zeros((N,window_shape[0],window_shape[1]),dtype=floatX)
    
    
    ##correctly order and reformat
    for ii,w in enumerate(windowIdx):
        str_dx = map(int, w.split('_'))
        dx = windows['index'].index(str_dx)
        W[ii] = windows['mask'][dx].clip(0,1)
    
    return W, resp, experiment, targetObjectMap,targetImage

# %% [markdown]
# ## Create data, test code

# %%
subject = 'AS'
state = 'img'
targetImage = 'candle_01'
windows, resp, experiment, targetObjectMap,targetImage = open_imagery_probe_data(subject, state, targetImage)

# %%
experiment.head()
# Out:
#        image  image_on     probe   resp_on  response state subj
# 0  candle_01  117.5410  11_12_21  127.8745       3.0   img   AS
# 1  candle_01  127.9244   15_7_16  139.0581       2.0   img   AS
# 2  candle_01  139.1078  32_24_33  151.4748       2.0   img   AS
# 3  candle_01  151.5415        37  156.2748       2.0   img   AS
# 4  candle_01  156.3414  18_10_19  163.0749       2.0   img   AS

# %%
_=plt.hist(resp.T)

# %%
targetImage.show()

# %% [markdown]
# ### Construct model variables

# %%
##number of objects
nObj = numObjects()

##dispersion on category prior: here we set a hyperprior
pDisp = priorDispersion()
dispersion = 2.2
pDisp.set_value(dispersion)

##resolution of object map Z
nPixels = numPixels()

##category prior and object map
catProb = categoryProbs(nObj,pDisp)
Z = latentObjMap(catProb,nPixels)

##noise params
nP = noiseParams()

##windows
desiredWindowShape = (375,600)
workingScale = 3
w = probes()
resolutions, workingResolution = w.resolve(desiredWindowShape, workingScale)
w.set_value(w.reshape(windows, workingResolution),flatten=True)
print 'working resolution is (%d, %d)' %(workingResolution[0], workingResolution[1])


##response object
r = responses(Z,nP)

##fake data
r.set_values(windows=w)

r.set_values(data=resp)

print 'total observations: %d' %(r.N)
# Out:
# working resolution is (30, 48)
# total observations: 345

# %%
tMap = target_image()
targetObjectMap_test, targetImage_test = tMap.reshape(targetObjectMap,workingResolution,targetImage=targetImage)
tMap.set_values(targetObjectMap_test, targetImage_test)

# %%
plt.imshow(tMap.targetObjectMap)

# %%
plt.imshow(tMap.targetImage,cmap='gray')

# %% [markdown]
# ### Define classes for the inferences we'll perform ($q(Z), q(\pi)$) and the optimizations (noise params).

# %%
##these are the variational inferences we want to perform
iqZ = inferQZ()
iqPi = inferQPi()

##this is the parameter optimization (point-estimate) we want
oNP = optimizeNoiseParams()

##variational inference combines them all together
vi = VI(r, iqZ,oNP, iqPi)

# %% [markdown]
# ### Run variational inference

# %%
##inference algorithm parameters
initialNoisinessOfZ = 0.2
pOn_init, pOff_init = .8, 0.2
densityOfNoiseParamGrid = 25
numStarterMaps = 10**2
numSamplesForComputingObjectCountProbs = 2
maxNumIterations = 50
trainTestSplit = 1.0
trainRegSplit = .8
pixelNumOverMin = 2
objectNumOverMin = 2

##set the pixel resolution hyperparameter range by hand
# vi.init_pixel_resolution_range(listOfTuples= [(4,6), (8,12)])
# vi.init_pixel_resolution_range(listOfTuples= [(6,9)])
# vi.init_pixel_resolution_range(listOfTuples= [(7,11)])#, (10,16)])

# %%
bestModel = vi.run_VI(initialNoisinessOfZ, \
                     pOn_init, pOff_init, \
                     densityOfNoiseParamGrid, \
                     numStarterMaps, \
                     numSamplesForComputingObjectCountProbs, \
                     maxNumIterations, \
                     trainTestSplit, trainRegSplit, \
                     optimizeHyperParams=True, pixelNumOverMin=pixelNumOverMin, objectNumOverMin=objectNumOverMin)
# Out:
# --------number of objects: 4------------
# --------image resolution: (5,8,40)------------
# !new best!
# ELBO: -370.668793
# goodness of fit: -395.745544
# posterior_entropy: 25.076754
# mean log of predictive distribution over test samples: -1.417875
# pecent correct over test samples: 35.294118
#
#
# !new best!
# ELBO: -293.267212
# goodness of fit: -317.147949
# posterior_entropy: 23.880747
# mean log of predictive distribution over test samples: -1.074302
# pecent correct over test samples: 58.823529
#
#
# ELBO: -236.629333
# goodness of fit: -252.518234
# posterior_entropy: 15.888898
# mean log of predictive distribution over test samples: -0.927616
# pecent correct over test samples: 54.411765
#
#
# !new best!
# ELBO: -223.326843
# goodness of fit: -232.021576
# posterior_entropy: 8.694736
# mean log of predictive distribution over test samples: -0.870730
# pecent correct over test samples: 64.705882
#
#
# ELBO: -201.474167
# goodness of fit: -208.856827
# posterior_entropy: 7.382661
# mean log of predictive distribution over test samples: -0.892482
# pecent correct over test samples: 61.764706
#
#
# ELBO: -196.779800
# goodness of fit: -202.398788
# posterior_entropy: 5.618984
# mean log of predictive distribution over test samples: -0.933435
# pecent correct over test samples: 61.764706
#
#
# ELBO: -183.794693
# goodness of fit: -187.893524
# posterior_entropy: 4.098829
# mean log of predictive distribution over test samples: -0.841938
# pecent correct over test samples: 64.705882
#
#
# !new best!
# ELBO: -203.560608
# goodness of fit: -207.816986
# posterior_entropy: 4.256376
# mean log of predictive distribution over test samples: -0.796638
# pecent correct over test samples: 67.647059
#
#
# ELBO: -171.512085
# goodness of fit: -175.512726
# posterior_entropy: 4.000638
# mean log of predictive distribution over test samples: -1.018414
# pecent correct over test samples: 63.235294
#
#
# ELBO: -173.375580
# goodness of fit: -175.999847
# posterior_entropy: 2.624269
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -173.964752
# goodness of fit: -176.959686
# posterior_entropy: 2.994940
# mean log of predictive distribution over test samples: -0.849323
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.257126
# goodness of fit: -175.512726
# posterior_entropy: 3.255599
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.994385
# goodness of fit: -175.999847
# posterior_entropy: 3.005463
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -175.033600
# goodness of fit: -177.634399
# posterior_entropy: 2.600792
# mean log of predictive distribution over test samples: -0.849323
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.543610
# goodness of fit: -175.512726
# posterior_entropy: 2.969113
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.020615
# goodness of fit: -175.025574
# posterior_entropy: 3.004956
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.974747
# goodness of fit: -175.999847
# posterior_entropy: 3.025095
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.918137
# goodness of fit: -175.512726
# posterior_entropy: 2.594591
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.519241
# goodness of fit: -175.512726
# posterior_entropy: 2.993486
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -173.350876
# goodness of fit: -175.999847
# posterior_entropy: 2.648975
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.519455
# goodness of fit: -175.512726
# posterior_entropy: 2.993276
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -173.350723
# goodness of fit: -175.999847
# posterior_entropy: 2.649122
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -173.004761
# goodness of fit: -175.999847
# posterior_entropy: 2.995080
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.490326
# goodness of fit: -175.512726
# posterior_entropy: 3.022393
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.980362
# goodness of fit: -175.999847
# posterior_entropy: 3.019481
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.980042
# goodness of fit: -175.999847
# posterior_entropy: 3.019802
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -173.340271
# goodness of fit: -175.999847
# posterior_entropy: 2.659570
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -173.368774
# goodness of fit: -175.999847
# posterior_entropy: 2.631079
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.514221
# goodness of fit: -175.512726
# posterior_entropy: 2.998497
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -174.410873
# goodness of fit: -177.434814
# posterior_entropy: 3.023940
# mean log of predictive distribution over test samples: -0.849323
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.673828
# goodness of fit: -175.999847
# posterior_entropy: 3.326016
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -178.948441
# goodness of fit: -182.741089
# posterior_entropy: 3.792649
# mean log of predictive distribution over test samples: -1.031810
# pecent correct over test samples: 61.764706
#
#
# ELBO: -179.245300
# goodness of fit: -182.741089
# posterior_entropy: 3.495790
# mean log of predictive distribution over test samples: -1.031810
# pecent correct over test samples: 61.764706
#
#
# ELBO: -178.735687
# goodness of fit: -182.253937
# posterior_entropy: 3.518251
# mean log of predictive distribution over test samples: -1.031810
# pecent correct over test samples: 61.764706
#
#
# ELBO: -177.986374
# goodness of fit: -182.253937
# posterior_entropy: 4.267557
# mean log of predictive distribution over test samples: -1.031810
# pecent correct over test samples: 61.764706
#
#
# ELBO: -178.428772
# goodness of fit: -182.741089
# posterior_entropy: 4.312322
# mean log of predictive distribution over test samples: -1.031810
# pecent correct over test samples: 61.764706
#
#
# ELBO: -182.976547
# goodness of fit: -186.954834
# posterior_entropy: 3.978289
# mean log of predictive distribution over test samples: -1.031810
# pecent correct over test samples: 61.764706
#
#
# ELBO: -178.309586
# goodness of fit: -182.253937
# posterior_entropy: 3.944357
# mean log of predictive distribution over test samples: -1.031810
# pecent correct over test samples: 61.764706
#
#
# ELBO: -177.975098
# goodness of fit: -182.253937
# posterior_entropy: 4.278837
# mean log of predictive distribution over test samples: -1.031810
# pecent correct over test samples: 61.764706
#
#
# ELBO: -183.678360
# goodness of fit: -187.991119
# posterior_entropy: 4.312766
# mean log of predictive distribution over test samples: -1.031810
# pecent correct over test samples: 61.764706
#
#
# ELBO: -177.936356
# goodness of fit: -182.253937
# posterior_entropy: 4.317577
# mean log of predictive distribution over test samples: -1.031810
# pecent correct over test samples: 61.764706
#
#
# ELBO: -180.875046
# goodness of fit: -184.478027
# posterior_entropy: 3.602975
# mean log of predictive distribution over test samples: -0.869168
# pecent correct over test samples: 61.764706
#
#
# ELBO: -174.888412
# goodness of fit: -178.584717
# posterior_entropy: 3.696305
# mean log of predictive distribution over test samples: -0.849323
# pecent correct over test samples: 63.235294
#
#
# ELBO: -174.574387
# goodness of fit: -178.017029
# posterior_entropy: 3.442649
# mean log of predictive distribution over test samples: -0.849323
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.390625
# goodness of fit: -175.512726
# posterior_entropy: 3.122102
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -175.396530
# goodness of fit: -178.396179
# posterior_entropy: 2.999647
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.980743
# goodness of fit: -175.999847
# posterior_entropy: 3.019108
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.491379
# goodness of fit: -175.512726
# posterior_entropy: 3.021346
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.491211
# goodness of fit: -175.512726
# posterior_entropy: 3.021518
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -173.347992
# goodness of fit: -175.999847
# posterior_entropy: 2.651850
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# ELBO: -172.517288
# goodness of fit: -175.512726
# posterior_entropy: 2.995439
# mean log of predictive distribution over test samples: -1.011522
# pecent correct over test samples: 63.235294
#
#
# --------image resolution: (10,16,160)------------
# !new best!
# ELBO: -408.026672
# goodness of fit: -502.632019
# posterior_entropy: 94.605362
# mean log of predictive distribution over test samples: -1.883680
# pecent correct over test samples: 20.588235
#
#
# !new best!
# ELBO: -147.060440
# goodness of fit: -336.229614
# posterior_entropy: 189.169174
# mean log of predictive distribution over test samples: -1.218103
# pecent correct over test samples: 50.000000
#
#
# !new best!
# ELBO: -121.710892
# goodness of fit: -330.475281
# posterior_entropy: 208.764389
# mean log of predictive distribution over test samples: -1.189595
# pecent correct over test samples: 51.470588
#
#
# !new best!
# ELBO: -135.456879
# goodness of fit: -338.883850
# posterior_entropy: 203.426971
# mean log of predictive distribution over test samples: -1.195047
# pecent correct over test samples: 54.411765
#
#
# ELBO: -129.315857
# goodness of fit: -333.307617
# posterior_entropy: 203.991760
# mean log of predictive distribution over test samples: -1.208125
# pecent correct over test samples: 50.000000
#
#
# ELBO: -132.646637
# goodness of fit: -336.260437
# posterior_entropy: 203.613800
# mean log of predictive distribution over test samples: -1.189381
# pecent correct over test samples: 54.411765
#
#
# ELBO: -133.823639
# goodness of fit: -335.226135
# posterior_entropy: 201.402496
# mean log of predictive distribution over test samples: -1.176288
# pecent correct over test samples: 50.000000
#
#
# ELBO: -130.104721
# goodness of fit: -319.960083
# posterior_entropy: 189.855362
# mean log of predictive distribution over test samples: -1.139621
# pecent correct over test samples: 54.411765
#
#
# !new best!
# ELBO: -132.172409
# goodness of fit: -306.878876
# posterior_entropy: 174.706467
# mean log of predictive distribution over test samples: -1.100366
# pecent correct over test samples: 55.882353
#
#
# !new best!
# ELBO: -138.423706
# goodness of fit: -302.989716
# posterior_entropy: 164.566010
# mean log of predictive distribution over test samples: -1.075397
# pecent correct over test samples: 63.235294
#
#
# ELBO: -142.959656
# goodness of fit: -294.505646
# posterior_entropy: 151.545990
# mean log of predictive distribution over test samples: -1.013224
# pecent correct over test samples: 57.352941
#
#
# ELBO: -132.494675
# goodness of fit: -274.837769
# posterior_entropy: 142.343094
# mean log of predictive distribution over test samples: -0.977326
# pecent correct over test samples: 54.411765
#
#
# ELBO: -128.535736
# goodness of fit: -259.917328
# posterior_entropy: 131.381592
# mean log of predictive distribution over test samples: -0.912134
# pecent correct over test samples: 55.882353
#
#
# ELBO: -125.741806
# goodness of fit: -253.111603
# posterior_entropy: 127.369797
# mean log of predictive distribution over test samples: -0.944894
# pecent correct over test samples: 52.941176
#
#
# ELBO: -148.874420
# goodness of fit: -270.082306
# posterior_entropy: 121.207893
# mean log of predictive distribution over test samples: -1.065613
# pecent correct over test samples: 47.058824
#
#
# ELBO: -130.963135
# goodness of fit: -257.365875
# posterior_entropy: 126.402740
# mean log of predictive distribution over test samples: -0.940426
# pecent correct over test samples: 50.000000
#
#
# ELBO: -155.984680
# goodness of fit: -274.555847
# posterior_entropy: 118.571159
# mean log of predictive distribution over test samples: -1.074677
# pecent correct over test samples: 54.411765
#
#
# ELBO: -135.031616
# goodness of fit: -258.010834
# posterior_entropy: 122.979210
# mean log of predictive distribution over test samples: -0.981107
# pecent correct over test samples: 48.529412
#
#
# ELBO: -132.897919
# goodness of fit: -257.108582
# posterior_entropy: 124.210655
# mean log of predictive distribution over test samples: -0.919950
# pecent correct over test samples: 51.470588
#
#
# ELBO: -131.583893
# goodness of fit: -252.484344
# posterior_entropy: 120.900444
# mean log of predictive distribution over test samples: -0.912241
# pecent correct over test samples: 54.411765
#
#
# ELBO: -132.043274
# goodness of fit: -250.022232
# posterior_entropy: 117.978951
# mean log of predictive distribution over test samples: -0.900029
# pecent correct over test samples: 52.941176
#
#
# ELBO: -132.580902
# goodness of fit: -252.987457
# posterior_entropy: 120.406555
# mean log of predictive distribution over test samples: -0.905616
# pecent correct over test samples: 52.941176
#
#
# ELBO: -135.989471
# goodness of fit: -257.831451
# posterior_entropy: 121.841980
# mean log of predictive distribution over test samples: -0.939977
# pecent correct over test samples: 50.000000
#
#
# ELBO: -142.232224
# goodness of fit: -265.217407
# posterior_entropy: 122.985184
# mean log of predictive distribution over test samples: -0.938872
# pecent correct over test samples: 52.941176
#
#
# ELBO: -118.894539
# goodness of fit: -243.810455
# posterior_entropy: 124.915916
# mean log of predictive distribution over test samples: -0.956348
# pecent correct over test samples: 50.000000
#
#
# ELBO: -128.323898
# goodness of fit: -244.860825
# posterior_entropy: 116.536926
# mean log of predictive distribution over test samples: -0.908463
# pecent correct over test samples: 50.000000
#
#
# ELBO: -134.470703
# goodness of fit: -247.862198
# posterior_entropy: 113.391502
# mean log of predictive distribution over test samples: -0.871380
# pecent correct over test samples: 54.411765
#
#
# ELBO: -133.758148
# goodness of fit: -244.385010
# posterior_entropy: 110.626854
# mean log of predictive distribution over test samples: -0.907423
# pecent correct over test samples: 51.470588
#
#
# ELBO: -135.983734
# goodness of fit: -243.793427
# posterior_entropy: 107.809692
# mean log of predictive distribution over test samples: -0.929904
# pecent correct over test samples: 38.235294
#
#
# ELBO: -131.255432
# goodness of fit: -237.305756
# posterior_entropy: 106.050331
# mean log of predictive distribution over test samples: -0.855578
# pecent correct over test samples: 51.470588
#
#
# ELBO: -147.677292
# goodness of fit: -242.114563
# posterior_entropy: 94.437271
# mean log of predictive distribution over test samples: -0.944055
# pecent correct over test samples: 47.058824
#
#
# ELBO: -152.074493
# goodness of fit: -246.048370
# posterior_entropy: 93.973869
# mean log of predictive distribution over test samples: -0.992147
# pecent correct over test samples: 42.647059
#
#
# ELBO: -151.765472
# goodness of fit: -237.163208
# posterior_entropy: 85.397736
# mean log of predictive distribution over test samples: -0.929809
# pecent correct over test samples: 51.470588
#
#
# ELBO: -148.550964
# goodness of fit: -216.526642
# posterior_entropy: 67.975685
# mean log of predictive distribution over test samples: -0.881781
# pecent correct over test samples: 61.764706
#
#
# ELBO: -152.257233
# goodness of fit: -209.446289
# posterior_entropy: 57.189049
# mean log of predictive distribution over test samples: -0.903450
# pecent correct over test samples: 51.470588
#
#
# !new best!
# ELBO: -166.553741
# goodness of fit: -213.223541
# posterior_entropy: 46.669796
# mean log of predictive distribution over test samples: -0.817356
# pecent correct over test samples: 64.705882
#
#
# ELBO: -145.648392
# goodness of fit: -182.354874
# posterior_entropy: 36.706482
# mean log of predictive distribution over test samples: -0.870112
# pecent correct over test samples: 58.823529
#
#
# !new best!
# ELBO: -139.413361
# goodness of fit: -170.642990
# posterior_entropy: 31.229633
# mean log of predictive distribution over test samples: -0.757565
# pecent correct over test samples: 72.058824
#
#
# ELBO: -129.422302
# goodness of fit: -153.042114
# posterior_entropy: 23.619816
# mean log of predictive distribution over test samples: -0.799390
# pecent correct over test samples: 67.647059
#
#
# ELBO: -131.136444
# goodness of fit: -151.715988
# posterior_entropy: 20.579550
# mean log of predictive distribution over test samples: -0.730980
# pecent correct over test samples: 72.058824
#
#
# ELBO: -142.047165
# goodness of fit: -162.681274
# posterior_entropy: 20.634104
# mean log of predictive distribution over test samples: -0.733157
# pecent correct over test samples: 72.058824
#
#
# ELBO: -134.132217
# goodness of fit: -153.615250
# posterior_entropy: 19.483032
# mean log of predictive distribution over test samples: -0.749623
# pecent correct over test samples: 67.647059
#
#
# ELBO: -134.452484
# goodness of fit: -154.450684
# posterior_entropy: 19.998205
# mean log of predictive distribution over test samples: -0.719527
# pecent correct over test samples: 72.058824
#
#
# ELBO: -135.860992
# goodness of fit: -156.163620
# posterior_entropy: 20.302620
# mean log of predictive distribution over test samples: -0.725774
# pecent correct over test samples: 72.058824
#
#
# ELBO: -136.396637
# goodness of fit: -156.831848
# posterior_entropy: 20.435207
# mean log of predictive distribution over test samples: -0.807209
# pecent correct over test samples: 66.176471
#
#
# ELBO: -137.320908
# goodness of fit: -158.701035
# posterior_entropy: 21.380129
# mean log of predictive distribution over test samples: -0.746530
# pecent correct over test samples: 70.588235
#
#
# ELBO: -136.459671
# goodness of fit: -158.058594
# posterior_entropy: 21.598927
# mean log of predictive distribution over test samples: -0.814613
# pecent correct over test samples: 66.176471
#
#
# ELBO: -154.085556
# goodness of fit: -176.423203
# posterior_entropy: 22.337646
# mean log of predictive distribution over test samples: -0.807236
# pecent correct over test samples: 67.647059
#
#
# ELBO: -134.559250
# goodness of fit: -154.714890
# posterior_entropy: 20.155640
# mean log of predictive distribution over test samples: -0.813752
# pecent correct over test samples: 67.647059
#
#
# ELBO: -158.135223
# goodness of fit: -174.618546
# posterior_entropy: 16.483330
# mean log of predictive distribution over test samples: -0.801109
# pecent correct over test samples: 69.117647
#
#
# ELBO: -133.943192
# goodness of fit: -153.615250
# posterior_entropy: 19.672060
# mean log of predictive distribution over test samples: -0.749377
# pecent correct over test samples: 69.117647
#
#
# --------number of objects: 5------------
# --------image resolution: (5,8,40)------------
# !new best!
# ELBO: -476.731781
# goodness of fit: -505.053864
# posterior_entropy: 28.322077
# mean log of predictive distribution over test samples: -1.776421
# pecent correct over test samples: 30.882353
#
#
# !new best!
# ELBO: -284.652924
# goodness of fit: -311.166199
# posterior_entropy: 26.513279
# mean log of predictive distribution over test samples: -1.004570
# pecent correct over test samples: 58.823529
#
#
# !new best!
# ELBO: -231.879288
# goodness of fit: -256.256195
# posterior_entropy: 24.376909
# mean log of predictive distribution over test samples: -0.869073
# pecent correct over test samples: 64.705882
#
#
# ELBO: -225.922531
# goodness of fit: -239.429138
# posterior_entropy: 13.506611
# mean log of predictive distribution over test samples: -0.957581
# pecent correct over test samples: 57.352941
#
#
# ELBO: -214.946136
# goodness of fit: -226.694260
# posterior_entropy: 11.748127
# mean log of predictive distribution over test samples: -0.968255
# pecent correct over test samples: 48.529412
#
#
# ELBO: -191.696472
# goodness of fit: -201.154114
# posterior_entropy: 9.457644
# mean log of predictive distribution over test samples: -1.115358
# pecent correct over test samples: 60.294118
#
#
# ELBO: -185.610947
# goodness of fit: -189.741730
# posterior_entropy: 4.130788
# mean log of predictive distribution over test samples: -0.863064
# pecent correct over test samples: 63.235294
#
#
# ELBO: -173.646072
# goodness of fit: -178.972565
# posterior_entropy: 5.326499
# mean log of predictive distribution over test samples: -1.108674
# pecent correct over test samples: 61.764706
#
#
# ELBO: -177.840714
# goodness of fit: -182.005341
# posterior_entropy: 4.164624
# mean log of predictive distribution over test samples: -0.882848
# pecent correct over test samples: 63.235294
#
#
# ELBO: -188.942169
# goodness of fit: -195.384628
# posterior_entropy: 6.442463
# mean log of predictive distribution over test samples: -0.882848
# pecent correct over test samples: 63.235294
#
#
# ELBO: -175.690750
# goodness of fit: -181.927826
# posterior_entropy: 6.237073
# mean log of predictive distribution over test samples: -0.878089
# pecent correct over test samples: 61.764706
#
#
# ELBO: -175.192551
# goodness of fit: -181.360138
# posterior_entropy: 6.167593
# mean log of predictive distribution over test samples: -0.882848
# pecent correct over test samples: 63.235294
#
#
# ELBO: -175.961334
# goodness of fit: -181.449615
# posterior_entropy: 5.488277
# mean log of predictive distribution over test samples: -0.878089
# pecent correct over test samples: 61.764706
#
#
# ELBO: -171.996902
# goodness of fit: -177.802734
# posterior_entropy: 5.805826
# mean log of predictive distribution over test samples: -1.108674
# pecent correct over test samples: 61.764706
#
#
# ELBO: -176.275620
# goodness of fit: -180.993927
# posterior_entropy: 4.718301
# mean log of predictive distribution over test samples: -1.056725
# pecent correct over test samples: 61.764706
#
#
# ELBO: -175.734970
# goodness of fit: -179.613510
# posterior_entropy: 3.878535
# mean log of predictive distribution over test samples: -1.056725
# pecent correct over test samples: 61.764706
#
#
# ELBO: -178.779236
# goodness of fit: -183.364609
# posterior_entropy: 4.585375
# mean log of predictive distribution over test samples: -1.067816
# pecent correct over test samples: 61.764706
#
#
# ELBO: -175.161255
# goodness of fit: -179.178436
# posterior_entropy: 4.017178
# mean log of predictive distribution over test samples: -1.106626
# pecent correct over test samples: 61.764706
#
#
# ELBO: -174.420639
# goodness of fit: -178.490585
# posterior_entropy: 4.069941
# mean log of predictive distribution over test samples: -1.106626
# pecent correct over test samples: 61.764706
#
#
# ELBO: -174.887726
# goodness of fit: -178.490585
# posterior_entropy: 3.602862
# mean log of predictive distribution over test samples: -1.121913
# pecent correct over test samples: 61.764706
#
#
# ELBO: -176.795609
# goodness of fit: -181.257507
# posterior_entropy: 4.461898
# mean log of predictive distribution over test samples: -1.056725
# pecent correct over test samples: 61.764706
#
#
# ELBO: -175.714951
# goodness of fit: -179.178436
# posterior_entropy: 3.463493
# mean log of predictive distribution over test samples: -1.106626
# pecent correct over test samples: 61.764706
#
#
# ELBO: -176.252991
# goodness of fit: -180.394958
# posterior_entropy: 4.141962
# mean log of predictive distribution over test samples: -0.882848
# pecent correct over test samples: 63.235294
#
#
# ELBO: -176.451614
# goodness of fit: -181.770721
# posterior_entropy: 5.319109
# mean log of predictive distribution over test samples: -0.888267
# pecent correct over test samples: 61.764706
#
#
# ELBO: -174.844879
# goodness of fit: -180.252716
# posterior_entropy: 5.407844
# mean log of predictive distribution over test samples: -0.893026
# pecent correct over test samples: 63.235294
#
#
# ELBO: -175.702698
# goodness of fit: -180.873169
# posterior_entropy: 5.170467
# mean log of predictive distribution over test samples: -0.878089
# pecent correct over test samples: 61.764706
#
#
# ELBO: -175.011322
# goodness of fit: -180.178589
# posterior_entropy: 5.167270
# mean log of predictive distribution over test samples: -0.882848
# pecent correct over test samples: 63.235294
#
#
# ELBO: -174.722961
# goodness of fit: -180.730911
# posterior_entropy: 6.007945
# mean log of predictive distribution over test samples: -0.882848
# pecent correct over test samples: 63.235294
#
#
# ELBO: -176.385132
# goodness of fit: -182.216965
# posterior_entropy: 5.831830
# mean log of predictive distribution over test samples: -0.878089
# pecent correct over test samples: 61.764706
#
#
# ELBO: -174.860031
# goodness of fit: -180.799042
# posterior_entropy: 5.939011
# mean log of predictive distribution over test samples: -0.878089
# pecent correct over test samples: 61.764706
#
#
# ELBO: -178.794952
# goodness of fit: -185.436478
# posterior_entropy: 6.641531
# mean log of predictive distribution over test samples: -0.874596
# pecent correct over test samples: 64.705882
#
#
# ELBO: -187.010681
# goodness of fit: -191.859741
# posterior_entropy: 4.849057
# mean log of predictive distribution over test samples: -0.900228
# pecent correct over test samples: 64.705882
#
#
# ELBO: -180.676712
# goodness of fit: -187.229736
# posterior_entropy: 6.553027
# mean log of predictive distribution over test samples: -0.882848
# pecent correct over test samples: 63.235294
#
#
# ELBO: -171.713913
# goodness of fit: -176.740768
# posterior_entropy: 5.026858
# mean log of predictive distribution over test samples: -1.174766
# pecent correct over test samples: 61.764706
#
#
# ELBO: -179.299896
# goodness of fit: -184.463303
# posterior_entropy: 5.163412
# mean log of predictive distribution over test samples: -1.069787
# pecent correct over test samples: 61.764706
#
#
# ELBO: -175.590805
# goodness of fit: -179.382111
# posterior_entropy: 3.791303
# mean log of predictive distribution over test samples: -1.056725
# pecent correct over test samples: 61.764706
#
#
# ELBO: -175.154282
# goodness of fit: -179.178436
# posterior_entropy: 4.024162
# mean log of predictive distribution over test samples: -1.121913
# pecent correct over test samples: 61.764706
#
#
# ELBO: -175.515228
# goodness of fit: -179.178436
# posterior_entropy: 3.663209
# mean log of predictive distribution over test samples: -1.121913
# pecent correct over test samples: 61.764706
#
#
# ELBO: -183.254944
# goodness of fit: -188.352051
# posterior_entropy: 5.097102
# mean log of predictive distribution over test samples: -0.872032
# pecent correct over test samples: 64.705882
#
#
# ELBO: -179.193695
# goodness of fit: -184.103012
# posterior_entropy: 4.909317
# mean log of predictive distribution over test samples: -0.878089
# pecent correct over test samples: 61.764706
#
#
# ELBO: -172.541901
# goodness of fit: -178.284698
# posterior_entropy: 5.742797
# mean log of predictive distribution over test samples: -1.108674
# pecent correct over test samples: 61.764706
#
#
# ELBO: -167.971695
# goodness of fit: -172.251083
# posterior_entropy: 4.279383
# mean log of predictive distribution over test samples: -1.116815
# pecent correct over test samples: 63.235294
#
#
# ELBO: -170.366180
# goodness of fit: -173.626801
# posterior_entropy: 3.260620
# mean log of predictive distribution over test samples: -1.116815
# pecent correct over test samples: 63.235294
#
#
# !new best!
# ELBO: -169.764771
# goodness of fit: -173.626801
# posterior_entropy: 3.862029
# mean log of predictive distribution over test samples: -1.093388
# pecent correct over test samples: 66.176471
#
#
# ELBO: -169.747986
# goodness of fit: -173.626801
# posterior_entropy: 3.878815
# mean log of predictive distribution over test samples: -1.116815
# pecent correct over test samples: 63.235294
#
#
# ELBO: -168.790848
# goodness of fit: -172.938950
# posterior_entropy: 4.148108
# mean log of predictive distribution over test samples: -1.116815
# pecent correct over test samples: 63.235294
#
#
# ELBO: -169.685776
# goodness of fit: -173.626801
# posterior_entropy: 3.941029
# mean log of predictive distribution over test samples: -1.116815
# pecent correct over test samples: 63.235294
#
#
# ELBO: -169.004807
# goodness of fit: -172.938950
# posterior_entropy: 3.934148
# mean log of predictive distribution over test samples: -1.116815
# pecent correct over test samples: 63.235294
#
#
# ELBO: -168.789154
# goodness of fit: -172.938950
# posterior_entropy: 4.149792
# mean log of predictive distribution over test samples: -1.116815
# pecent correct over test samples: 63.235294
#
#
# ELBO: -168.785477
# goodness of fit: -172.938950
# posterior_entropy: 4.153468
# mean log of predictive distribution over test samples: -1.116815
# pecent correct over test samples: 63.235294
#
#
# ELBO: -170.964294
# goodness of fit: -175.047379
# posterior_entropy: 4.083091
# mean log of predictive distribution over test samples: -1.063257
# pecent correct over test samples: 66.176471
#
#
# --------image resolution: (10,16,160)------------
# !new best!
# ELBO: -582.074951
# goodness of fit: -689.347107
# posterior_entropy: 107.272148
# mean log of predictive distribution over test samples: -2.731238
# pecent correct over test samples: 2.941176
#
#
# !new best!
# ELBO: -166.603424
# goodness of fit: -343.989868
# posterior_entropy: 177.386444
# mean log of predictive distribution over test samples: -1.222166
# pecent correct over test samples: 45.588235
#
#
# !new best!
# ELBO: -115.326202
# goodness of fit: -312.549438
# posterior_entropy: 197.223236
# mean log of predictive distribution over test samples: -1.092519
# pecent correct over test samples: 54.411765
#
#
# ELBO: -106.894791
# goodness of fit: -308.546204
# posterior_entropy: 201.651413
# mean log of predictive distribution over test samples: -1.088159
# pecent correct over test samples: 52.941176
#
#
# !new best!
# ELBO: -117.043976
# goodness of fit: -310.652710
# posterior_entropy: 193.608734
# mean log of predictive distribution over test samples: -1.090248
# pecent correct over test samples: 60.294118
#
#
# ELBO: -124.216614
# goodness of fit: -307.789978
# posterior_entropy: 183.573364
# mean log of predictive distribution over test samples: -1.071511
# pecent correct over test samples: 58.823529
#
#
# ELBO: -124.533051
# goodness of fit: -301.096802
# posterior_entropy: 176.563751
# mean log of predictive distribution over test samples: -1.123455
# pecent correct over test samples: 57.352941
#
#
# ELBO: -121.998215
# goodness of fit: -299.198975
# posterior_entropy: 177.200760
# mean log of predictive distribution over test samples: -1.064731
# pecent correct over test samples: 52.941176
#
#
# !new best!
# ELBO: -127.090088
# goodness of fit: -307.460052
# posterior_entropy: 180.369965
# mean log of predictive distribution over test samples: -1.079726
# pecent correct over test samples: 61.764706
#
#
# ELBO: -117.816315
# goodness of fit: -299.796906
# posterior_entropy: 181.980591
# mean log of predictive distribution over test samples: -1.073299
# pecent correct over test samples: 60.294118
#
#
# ELBO: -124.577469
# goodness of fit: -301.024261
# posterior_entropy: 176.446793
# mean log of predictive distribution over test samples: -1.112051
# pecent correct over test samples: 52.941176
#
#
# !new best!
# ELBO: -129.321182
# goodness of fit: -303.608765
# posterior_entropy: 174.287582
# mean log of predictive distribution over test samples: -1.025545
# pecent correct over test samples: 64.705882
#
#
# ELBO: -128.110062
# goodness of fit: -290.578247
# posterior_entropy: 162.468185
# mean log of predictive distribution over test samples: -1.048138
# pecent correct over test samples: 61.764706
#
#
# !new best!
# ELBO: -137.477875
# goodness of fit: -290.271606
# posterior_entropy: 152.793732
# mean log of predictive distribution over test samples: -1.017973
# pecent correct over test samples: 66.176471
#
#
# !new best!
# ELBO: -137.780899
# goodness of fit: -286.976257
# posterior_entropy: 149.195358
# mean log of predictive distribution over test samples: -1.004184
# pecent correct over test samples: 70.588235
#
#
# ELBO: -135.704468
# goodness of fit: -278.997528
# posterior_entropy: 143.293060
# mean log of predictive distribution over test samples: -0.959205
# pecent correct over test samples: 66.176471
#
#
# ELBO: -135.159042
# goodness of fit: -272.642761
# posterior_entropy: 137.483719
# mean log of predictive distribution over test samples: -1.025138
# pecent correct over test samples: 61.764706
#
#
# ELBO: -134.550415
# goodness of fit: -274.979004
# posterior_entropy: 140.428589
# mean log of predictive distribution over test samples: -1.002958
# pecent correct over test samples: 48.529412
#
#
# ELBO: -153.015839
# goodness of fit: -285.266785
# posterior_entropy: 132.250946
# mean log of predictive distribution over test samples: -1.060827
# pecent correct over test samples: 45.588235
#
#
# ELBO: -141.522430
# goodness of fit: -271.469452
# posterior_entropy: 129.947021
# mean log of predictive distribution over test samples: -0.922285
# pecent correct over test samples: 51.470588
#
#
# ELBO: -145.783066
# goodness of fit: -275.236694
# posterior_entropy: 129.453629
# mean log of predictive distribution over test samples: -0.984243
# pecent correct over test samples: 54.411765
#
#
# ELBO: -130.524017
# goodness of fit: -257.811401
# posterior_entropy: 127.287392
# mean log of predictive distribution over test samples: -0.941341
# pecent correct over test samples: 55.882353
#
#
# ELBO: -130.205383
# goodness of fit: -258.675140
# posterior_entropy: 128.469757
# mean log of predictive distribution over test samples: -0.960061
# pecent correct over test samples: 50.000000
#
#
# ELBO: -145.706451
# goodness of fit: -273.294891
# posterior_entropy: 127.588448
# mean log of predictive distribution over test samples: -0.980061
# pecent correct over test samples: 50.000000
#
#
# ELBO: -140.320221
# goodness of fit: -262.537933
# posterior_entropy: 122.217712
# mean log of predictive distribution over test samples: -0.903191
# pecent correct over test samples: 60.294118
#
#
# ELBO: -129.728424
# goodness of fit: -257.975372
# posterior_entropy: 128.246948
# mean log of predictive distribution over test samples: -0.912242
# pecent correct over test samples: 57.352941
#
#
# ELBO: -128.945282
# goodness of fit: -253.039627
# posterior_entropy: 124.094353
# mean log of predictive distribution over test samples: -0.929318
# pecent correct over test samples: 51.470588
#
#
# ELBO: -141.030945
# goodness of fit: -260.042603
# posterior_entropy: 119.011658
# mean log of predictive distribution over test samples: -0.956415
# pecent correct over test samples: 57.352941
#
#
# ELBO: -142.091797
# goodness of fit: -266.010193
# posterior_entropy: 123.918396
# mean log of predictive distribution over test samples: -0.907882
# pecent correct over test samples: 52.941176
#
#
# ELBO: -133.305527
# goodness of fit: -257.291840
# posterior_entropy: 123.986313
# mean log of predictive distribution over test samples: -0.909883
# pecent correct over test samples: 55.882353
#
#
# ELBO: -131.469925
# goodness of fit: -255.248627
# posterior_entropy: 123.778702
# mean log of predictive distribution over test samples: -0.981983
# pecent correct over test samples: 47.058824
#
#
# ELBO: -133.741501
# goodness of fit: -259.032074
# posterior_entropy: 125.290573
# mean log of predictive distribution over test samples: -0.900100
# pecent correct over test samples: 57.352941
#
#
# ELBO: -129.453094
# goodness of fit: -248.036896
# posterior_entropy: 118.583794
# mean log of predictive distribution over test samples: -0.898155
# pecent correct over test samples: 58.823529
#
#
# ELBO: -132.737122
# goodness of fit: -249.925964
# posterior_entropy: 117.188835
# mean log of predictive distribution over test samples: -0.893090
# pecent correct over test samples: 55.882353
#
#
# ELBO: -129.949310
# goodness of fit: -244.956299
# posterior_entropy: 115.006989
# mean log of predictive distribution over test samples: -0.902436
# pecent correct over test samples: 52.941176
#
#
# ELBO: -129.766113
# goodness of fit: -242.889328
# posterior_entropy: 113.123207
# mean log of predictive distribution over test samples: -0.867818
# pecent correct over test samples: 55.882353
#
#
# ELBO: -128.895676
# goodness of fit: -244.553833
# posterior_entropy: 115.658157
# mean log of predictive distribution over test samples: -0.884979
# pecent correct over test samples: 45.588235
#
#
# ELBO: -132.670227
# goodness of fit: -243.920532
# posterior_entropy: 111.250313
# mean log of predictive distribution over test samples: -0.919415
# pecent correct over test samples: 45.588235
#
#
# ELBO: -133.049652
# goodness of fit: -244.275513
# posterior_entropy: 111.225861
# mean log of predictive distribution over test samples: -1.041701
# pecent correct over test samples: 45.588235
#
#
# ELBO: -130.561646
# goodness of fit: -242.336609
# posterior_entropy: 111.774963
# mean log of predictive distribution over test samples: -1.042254
# pecent correct over test samples: 48.529412
#
#
# ELBO: -127.336021
# goodness of fit: -242.697723
# posterior_entropy: 115.361702
# mean log of predictive distribution over test samples: -0.853383
# pecent correct over test samples: 48.529412
#
#
# ELBO: -138.766815
# goodness of fit: -250.881851
# posterior_entropy: 112.115028
# mean log of predictive distribution over test samples: -0.890320
# pecent correct over test samples: 42.647059
#
#
# ELBO: -128.958450
# goodness of fit: -237.927841
# posterior_entropy: 108.969391
# mean log of predictive distribution over test samples: -0.967598
# pecent correct over test samples: 42.647059
#
#
# ELBO: -129.983429
# goodness of fit: -240.979980
# posterior_entropy: 110.996559
# mean log of predictive distribution over test samples: -0.957394
# pecent correct over test samples: 47.058824
#
#
# ELBO: -132.195770
# goodness of fit: -242.281952
# posterior_entropy: 110.086182
# mean log of predictive distribution over test samples: -0.985488
# pecent correct over test samples: 39.705882
#
#
# ELBO: -143.000687
# goodness of fit: -250.860641
# posterior_entropy: 107.859955
# mean log of predictive distribution over test samples: -0.887992
# pecent correct over test samples: 57.352941
#
#
# ELBO: -137.480667
# goodness of fit: -246.809372
# posterior_entropy: 109.328705
# mean log of predictive distribution over test samples: -0.880938
# pecent correct over test samples: 58.823529
#
#
# ELBO: -135.366562
# goodness of fit: -243.760071
# posterior_entropy: 108.393509
# mean log of predictive distribution over test samples: -0.952906
# pecent correct over test samples: 52.941176
#
#
# ELBO: -134.767944
# goodness of fit: -239.671310
# posterior_entropy: 104.903366
# mean log of predictive distribution over test samples: -0.971184
# pecent correct over test samples: 41.176471
#
#
# ELBO: -150.518738
# goodness of fit: -247.578506
# posterior_entropy: 97.059776
# mean log of predictive distribution over test samples: -0.970528
# pecent correct over test samples: 42.647059
#
#
# ELBO: -150.906219
# goodness of fit: -246.748016
# posterior_entropy: 95.841789
# mean log of predictive distribution over test samples: -0.958846
# pecent correct over test samples: 45.588235
#
#
# --------number of objects: 6------------
# --------image resolution: (5,8,40)------------
# !new best!
# ELBO: -635.093384
# goodness of fit: -665.308960
# posterior_entropy: 30.215559
# mean log of predictive distribution over test samples: -2.296064
# pecent correct over test samples: 5.882353
#
#
# !new best!
# ELBO: -303.869446
# goodness of fit: -320.403046
# posterior_entropy: 16.533600
# mean log of predictive distribution over test samples: -1.132497
# pecent correct over test samples: 47.058824
#
#
# !new best!
# ELBO: -240.211182
# goodness of fit: -257.503540
# posterior_entropy: 17.292351
# mean log of predictive distribution over test samples: -0.897977
# pecent correct over test samples: 66.176471
#
#
# ELBO: -238.413055
# goodness of fit: -251.310837
# posterior_entropy: 12.897777
# mean log of predictive distribution over test samples: -0.929455
# pecent correct over test samples: 54.411765
#
#
# ELBO: -192.506531
# goodness of fit: -201.728470
# posterior_entropy: 9.221947
# mean log of predictive distribution over test samples: -0.966174
# pecent correct over test samples: 63.235294
#
#
# ELBO: -219.671448
# goodness of fit: -225.653793
# posterior_entropy: 5.982346
# mean log of predictive distribution over test samples: -0.870342
# pecent correct over test samples: 63.235294
#
#
# ELBO: -176.521866
# goodness of fit: -184.589859
# posterior_entropy: 8.067989
# mean log of predictive distribution over test samples: -1.019185
# pecent correct over test samples: 60.294118
#
#
# ELBO: -167.379501
# goodness of fit: -172.893692
# posterior_entropy: 5.514194
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -167.842194
# goodness of fit: -173.380981
# posterior_entropy: 5.538790
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -171.708084
# goodness of fit: -178.054657
# posterior_entropy: 6.346568
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -167.860794
# goodness of fit: -173.380981
# posterior_entropy: 5.520189
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -167.690628
# goodness of fit: -172.893692
# posterior_entropy: 5.203057
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -167.865982
# goodness of fit: -173.380981
# posterior_entropy: 5.515005
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -168.032104
# goodness of fit: -173.380981
# posterior_entropy: 5.348871
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -191.761963
# goodness of fit: -197.963196
# posterior_entropy: 6.201227
# mean log of predictive distribution over test samples: -0.904641
# pecent correct over test samples: 63.235294
#
#
# ELBO: -185.960037
# goodness of fit: -194.219925
# posterior_entropy: 8.259882
# mean log of predictive distribution over test samples: -0.880626
# pecent correct over test samples: 58.823529
#
#
# ELBO: -192.865463
# goodness of fit: -201.099731
# posterior_entropy: 8.234262
# mean log of predictive distribution over test samples: -0.842894
# pecent correct over test samples: 64.705882
#
#
# !new best!
# ELBO: -183.087967
# goodness of fit: -190.972122
# posterior_entropy: 7.884162
# mean log of predictive distribution over test samples: -0.986397
# pecent correct over test samples: 67.647059
#
#
# ELBO: -175.693604
# goodness of fit: -180.516449
# posterior_entropy: 4.822841
# mean log of predictive distribution over test samples: -0.926895
# pecent correct over test samples: 64.705882
#
#
# ELBO: -169.010605
# goodness of fit: -173.380981
# posterior_entropy: 4.370372
# mean log of predictive distribution over test samples: -0.946244
# pecent correct over test samples: 66.176471
#
#
# ELBO: -168.044937
# goodness of fit: -173.380981
# posterior_entropy: 5.336047
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -170.920090
# goodness of fit: -175.963379
# posterior_entropy: 5.043296
# mean log of predictive distribution over test samples: -1.050304
# pecent correct over test samples: 60.294118
#
#
# ELBO: -168.377701
# goodness of fit: -173.380981
# posterior_entropy: 5.003282
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -172.969772
# goodness of fit: -178.054657
# posterior_entropy: 5.084891
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -168.556763
# goodness of fit: -173.380981
# posterior_entropy: 4.824223
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -167.499405
# goodness of fit: -172.893692
# posterior_entropy: 5.394280
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -167.177277
# goodness of fit: -172.893692
# posterior_entropy: 5.716410
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -167.820358
# goodness of fit: -173.380981
# posterior_entropy: 5.560630
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -167.702911
# goodness of fit: -172.893692
# posterior_entropy: 5.190777
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -181.496826
# goodness of fit: -186.823395
# posterior_entropy: 5.326576
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -168.454025
# goodness of fit: -173.380981
# posterior_entropy: 4.926959
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -168.446091
# goodness of fit: -173.380981
# posterior_entropy: 4.934897
# mean log of predictive distribution over test samples: -1.052776
# pecent correct over test samples: 60.294118
#
#
# ELBO: -181.045990
# goodness of fit: -186.823395
# posterior_entropy: 5.777400
# mean log of predictive distribution over test samples: -1.024462
# pecent correct over test samples: 63.235294
#
#
# ELBO: -168.495026
# goodness of fit: -173.380981
# posterior_entropy: 4.885955
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -171.516098
# goodness of fit: -178.054657
# posterior_entropy: 6.538554
# mean log of predictive distribution over test samples: -1.028340
# pecent correct over test samples: 63.235294
#
#
# ELBO: -166.974213
# goodness of fit: -173.380981
# posterior_entropy: 6.406773
# mean log of predictive distribution over test samples: -1.024462
# pecent correct over test samples: 63.235294
#
#
# ELBO: -167.316681
# goodness of fit: -172.893692
# posterior_entropy: 5.577010
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -167.379150
# goodness of fit: -173.380981
# posterior_entropy: 6.001834
# mean log of predictive distribution over test samples: -1.024462
# pecent correct over test samples: 63.235294
#
#
# ELBO: -167.485519
# goodness of fit: -173.380981
# posterior_entropy: 5.895466
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -168.427536
# goodness of fit: -173.380981
# posterior_entropy: 4.953440
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -168.026825
# goodness of fit: -173.380981
# posterior_entropy: 5.354158
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -181.690582
# goodness of fit: -186.823395
# posterior_entropy: 5.132811
# mean log of predictive distribution over test samples: -1.014777
# pecent correct over test samples: 63.235294
#
#
# ELBO: -168.218277
# goodness of fit: -173.380981
# posterior_entropy: 5.162697
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -168.452942
# goodness of fit: -173.380981
# posterior_entropy: 4.928035
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -186.353333
# goodness of fit: -191.784424
# posterior_entropy: 5.431098
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -168.038391
# goodness of fit: -173.380981
# posterior_entropy: 5.342592
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -168.177429
# goodness of fit: -173.380981
# posterior_entropy: 5.203550
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -168.231628
# goodness of fit: -173.380981
# posterior_entropy: 5.149353
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -168.615875
# goodness of fit: -173.380981
# posterior_entropy: 4.765110
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# ELBO: -175.230728
# goodness of fit: -181.296143
# posterior_entropy: 6.065419
# mean log of predictive distribution over test samples: -1.024462
# pecent correct over test samples: 63.235294
#
#
# ELBO: -178.129456
# goodness of fit: -183.182266
# posterior_entropy: 5.052811
# mean log of predictive distribution over test samples: -1.039212
# pecent correct over test samples: 60.294118
#
#
# --------image resolution: (10,16,160)------------
# ELBO: -804.928650
# goodness of fit: -935.016968
# posterior_entropy: 130.088318
# mean log of predictive distribution over test samples: -3.359109
# pecent correct over test samples: 0.000000
#
#
# !new best!
# ELBO: -185.088928
# goodness of fit: -350.260010
# posterior_entropy: 165.171082
# mean log of predictive distribution over test samples: -1.201211
# pecent correct over test samples: 55.882353
#
#
# ELBO: -113.198318
# goodness of fit: -324.574036
# posterior_entropy: 211.375717
# mean log of predictive distribution over test samples: -1.169241
# pecent correct over test samples: 47.058824
#
#
# ELBO: -105.518814
# goodness of fit: -317.680298
# posterior_entropy: 212.161484
# mean log of predictive distribution over test samples: -1.110078
# pecent correct over test samples: 55.882353
#
#
# ELBO: -97.156189
# goodness of fit: -308.329132
# posterior_entropy: 211.172943
# mean log of predictive distribution over test samples: -1.142638
# pecent correct over test samples: 47.058824
#
#
# ELBO: -109.480072
# goodness of fit: -311.564545
# posterior_entropy: 202.084473
# mean log of predictive distribution over test samples: -1.118839
# pecent correct over test samples: 55.882353
#
#
# !new best!
# ELBO: -110.626526
# goodness of fit: -307.144501
# posterior_entropy: 196.517975
# mean log of predictive distribution over test samples: -1.076250
# pecent correct over test samples: 61.764706
#
#
# !new best!
# ELBO: -108.963287
# goodness of fit: -304.775696
# posterior_entropy: 195.812408
# mean log of predictive distribution over test samples: -1.076015
# pecent correct over test samples: 63.235294
#
#
# ELBO: -113.408936
# goodness of fit: -308.676361
# posterior_entropy: 195.267426
# mean log of predictive distribution over test samples: -1.074876
# pecent correct over test samples: 51.470588
#
#
# ELBO: -112.730576
# goodness of fit: -297.430847
# posterior_entropy: 184.700272
# mean log of predictive distribution over test samples: -1.082379
# pecent correct over test samples: 60.294118
#
#
# ELBO: -118.474213
# goodness of fit: -292.097168
# posterior_entropy: 173.622955
# mean log of predictive distribution over test samples: -1.025213
# pecent correct over test samples: 60.294118
#
#
# !new best!
# ELBO: -132.231323
# goodness of fit: -294.932617
# posterior_entropy: 162.701294
# mean log of predictive distribution over test samples: -1.042063
# pecent correct over test samples: 64.705882
#
#
# !new best!
# ELBO: -119.823792
# goodness of fit: -279.478333
# posterior_entropy: 159.654541
# mean log of predictive distribution over test samples: -1.025109
# pecent correct over test samples: 69.117647
#
#
# ELBO: -132.542557
# goodness of fit: -285.711243
# posterior_entropy: 153.168686
# mean log of predictive distribution over test samples: -1.039094
# pecent correct over test samples: 52.941176
#
#
# ELBO: -131.812408
# goodness of fit: -266.307373
# posterior_entropy: 134.494965
# mean log of predictive distribution over test samples: -0.923872
# pecent correct over test samples: 60.294118
#
#
# ELBO: -130.483749
# goodness of fit: -261.838287
# posterior_entropy: 131.354538
# mean log of predictive distribution over test samples: -0.953854
# pecent correct over test samples: 47.058824
#
#
# ELBO: -142.474792
# goodness of fit: -264.828796
# posterior_entropy: 122.353996
# mean log of predictive distribution over test samples: -1.023219
# pecent correct over test samples: 52.941176
#
#
# ELBO: -136.766388
# goodness of fit: -260.981476
# posterior_entropy: 124.215088
# mean log of predictive distribution over test samples: -0.930521
# pecent correct over test samples: 57.352941
#
#
# ELBO: -143.618378
# goodness of fit: -260.074432
# posterior_entropy: 116.456062
# mean log of predictive distribution over test samples: -0.961733
# pecent correct over test samples: 54.411765
#
#
# ELBO: -142.688721
# goodness of fit: -266.397491
# posterior_entropy: 123.708778
# mean log of predictive distribution over test samples: -0.927643
# pecent correct over test samples: 57.352941
#
#
# ELBO: -127.413269
# goodness of fit: -257.748199
# posterior_entropy: 130.334930
# mean log of predictive distribution over test samples: -1.006513
# pecent correct over test samples: 50.000000
#
#
# ELBO: -136.433853
# goodness of fit: -256.847198
# posterior_entropy: 120.413345
# mean log of predictive distribution over test samples: -0.873619
# pecent correct over test samples: 60.294118
#
#
# ELBO: -136.818420
# goodness of fit: -255.760025
# posterior_entropy: 118.941597
# mean log of predictive distribution over test samples: -0.905953
# pecent correct over test samples: 58.823529
#
#
# ELBO: -119.957123
# goodness of fit: -240.063477
# posterior_entropy: 120.106354
# mean log of predictive distribution over test samples: -0.859928
# pecent correct over test samples: 57.352941
#
#
# ELBO: -125.918037
# goodness of fit: -240.379669
# posterior_entropy: 114.461632
# mean log of predictive distribution over test samples: -0.923241
# pecent correct over test samples: 60.294118
#
#
# ELBO: -140.902878
# goodness of fit: -254.516922
# posterior_entropy: 113.614044
# mean log of predictive distribution over test samples: -0.880599
# pecent correct over test samples: 51.470588
#
#
# ELBO: -126.527710
# goodness of fit: -244.786682
# posterior_entropy: 118.258972
# mean log of predictive distribution over test samples: -0.886845
# pecent correct over test samples: 58.823529
#
#
# ELBO: -139.138031
# goodness of fit: -255.546280
# posterior_entropy: 116.408241
# mean log of predictive distribution over test samples: -0.897810
# pecent correct over test samples: 51.470588
#
#
# ELBO: -145.402161
# goodness of fit: -265.444305
# posterior_entropy: 120.042137
# mean log of predictive distribution over test samples: -0.882564
# pecent correct over test samples: 57.352941
#
#
# ELBO: -145.312744
# goodness of fit: -268.240845
# posterior_entropy: 122.928101
# mean log of predictive distribution over test samples: -1.019934
# pecent correct over test samples: 42.647059
#
#
# ELBO: -129.883514
# goodness of fit: -251.059235
# posterior_entropy: 121.175720
# mean log of predictive distribution over test samples: -0.882282
# pecent correct over test samples: 52.941176
#
#
# ELBO: -132.771500
# goodness of fit: -249.679260
# posterior_entropy: 116.907761
# mean log of predictive distribution over test samples: -0.874208
# pecent correct over test samples: 54.411765
#
#
# ELBO: -143.413757
# goodness of fit: -258.172272
# posterior_entropy: 114.758522
# mean log of predictive distribution over test samples: -0.868616
# pecent correct over test samples: 52.941176
#
#
# ELBO: -135.379852
# goodness of fit: -246.064636
# posterior_entropy: 110.684776
# mean log of predictive distribution over test samples: -0.965641
# pecent correct over test samples: 45.588235
#
#
# ELBO: -142.191223
# goodness of fit: -254.669647
# posterior_entropy: 112.478416
# mean log of predictive distribution over test samples: -0.914584
# pecent correct over test samples: 42.647059
#
#
# ELBO: -141.424927
# goodness of fit: -251.061340
# posterior_entropy: 109.636406
# mean log of predictive distribution over test samples: -0.893622
# pecent correct over test samples: 55.882353
#
#
# ELBO: -127.703362
# goodness of fit: -236.872772
# posterior_entropy: 109.169411
# mean log of predictive distribution over test samples: -0.919208
# pecent correct over test samples: 41.176471
#
#
# ELBO: -145.169098
# goodness of fit: -246.840134
# posterior_entropy: 101.671036
# mean log of predictive distribution over test samples: -1.010621
# pecent correct over test samples: 48.529412
#
#
# ELBO: -148.150909
# goodness of fit: -250.617783
# posterior_entropy: 102.466881
# mean log of predictive distribution over test samples: -1.007740
# pecent correct over test samples: 61.764706
#
#
# ELBO: -144.752197
# goodness of fit: -240.872192
# posterior_entropy: 96.119987
# mean log of predictive distribution over test samples: -0.933640
# pecent correct over test samples: 51.470588
#
#
# ELBO: -139.276779
# goodness of fit: -234.881851
# posterior_entropy: 95.605072
# mean log of predictive distribution over test samples: -0.903388
# pecent correct over test samples: 44.117647
#
#
# ELBO: -161.532410
# goodness of fit: -246.174667
# posterior_entropy: 84.642258
# mean log of predictive distribution over test samples: -1.016766
# pecent correct over test samples: 50.000000
#
#
# ELBO: -142.681488
# goodness of fit: -228.510010
# posterior_entropy: 85.828514
# mean log of predictive distribution over test samples: -0.965041
# pecent correct over test samples: 55.882353
#
#
# ELBO: -143.619720
# goodness of fit: -228.887848
# posterior_entropy: 85.268120
# mean log of predictive distribution over test samples: -0.981622
# pecent correct over test samples: 51.470588
#
#
# ELBO: -169.236237
# goodness of fit: -252.830795
# posterior_entropy: 83.594566
# mean log of predictive distribution over test samples: -0.934912
# pecent correct over test samples: 48.529412
#
#
# ELBO: -139.182983
# goodness of fit: -215.904144
# posterior_entropy: 76.721153
# mean log of predictive distribution over test samples: -0.964516
# pecent correct over test samples: 45.588235
#
#
# ELBO: -163.263718
# goodness of fit: -227.090714
# posterior_entropy: 63.827000
# mean log of predictive distribution over test samples: -0.966511
# pecent correct over test samples: 51.470588
#
#
# ELBO: -173.984863
# goodness of fit: -238.134918
# posterior_entropy: 64.150055
# mean log of predictive distribution over test samples: -0.930336
# pecent correct over test samples: 57.352941
#
#
# ELBO: -177.468918
# goodness of fit: -238.259033
# posterior_entropy: 60.790112
# mean log of predictive distribution over test samples: -0.986636
# pecent correct over test samples: 50.000000
#
#
# ELBO: -168.598572
# goodness of fit: -231.553024
# posterior_entropy: 62.954453
# mean log of predictive distribution over test samples: -0.890190
# pecent correct over test samples: 51.470588
#
#
# ELBO: -149.897995
# goodness of fit: -211.875061
# posterior_entropy: 61.977066
# mean log of predictive distribution over test samples: -0.878167
# pecent correct over test samples: 52.941176
# /home/tnaselar/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:388: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/tnaselar/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:389: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/tnaselar/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:390: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
bestModel.bestNoiseParam
# Out:
# array([ 0.91583335,  0.04253788], dtype=float32)

# %%
bestModel.bestPercentCorrect
# Out:
# array([ 72.05882353])

# %%
fig, ax = plt.subplots()
ax.plot(bestModel.percentCorrect_history[:bestModel.numIters])
ax.set_xlabel('iteration', color='b')
ax.set_ylabel('precent correct', color='b')
ax.tick_params('y', colors='b')


ax2 = ax.twinx()
ax2.plot(bestModel.lnPredictiveDistribution_history[:bestModel.numIters], 'r')
ax2.set_ylabel('pred. dist', color='r')
ax2.tick_params('y', colors='r')

# %%
fig, ax = plt.subplots()
ax.plot(bestModel.goodnessOfFitStar_history[:bestModel.numIters])
ax.set_xlabel('iteration', color='b')
ax.set_ylabel('goodness of fit', color='b')
ax.tick_params('y', colors='b')


ax2 = ax.twinx()
ax2.plot(bestModel.posteriorEntropy_history[:bestModel.numIters], 'r')
ax2.set_ylabel('posterior entropy', color='r')
ax2.tick_params('y', colors='r')

# %%
plt.plot(bestModel.ELBO_history[:bestModel.numIters])

# %%
bestModel.see_Q_Z(bestModel.bestQZ)

# %%
sampZ = bestModel.responses.Z.sample(M=1,pZ=bestModel.bestQZ)
_=bestModel.responses.Z.view_sample(sampZ)

# %%
def see_posterior_overlay(Q_Z, Z, image_dimensions):
    '''
    Q_Z ~ K x D
      Z ~ K x D
    '''
    ##view: construct an image grid
    fig = plt.figure(1, (40,20))
    K = Q_Z.shape[0]
    grid = ImageGrid(fig, 111, # similar to subplot(111)
                    nrows_ncols = (1, K), # creates grid of axes
                    axes_pad=0.5, # pad between axes in inch.
                    cbar_mode = 'each',
                    cbar_pad = .05
                    )
    
    colors = [(0, 0, 0), (1., 1., 0)]
    cm_1 = LinearSegmentedColormap.from_list(
        'object_map', colors, N=2)

    colors = [(0, 0, 0), (0., 0., 1.)]
    cm_2 = LinearSegmentedColormap.from_list(
        'prob', colors, N=20)

    
    log_prob = object_confusion(Q_Z, Z)
    Q_Z = Q_Z.reshape((K, image_dimensions[0],image_dimensions[1]))
    Z = Z.reshape((K, image_dimensions[0], image_dimensions[1]))
    for k in range(K):
        
        max_k,max_j = np.unravel_index(np.argmax(log_prob), log_prob.shape)
        log_prob[max_k,:] = -np.inf
        log_prob[:,max_j] = -np.inf
        grid[k].imshow(Z[max_j],cmap=cm_1)
        grid[k].imshow(Q_Z[max_k], cmap=cm_2, clim=[0,1], alpha = 0.6)
